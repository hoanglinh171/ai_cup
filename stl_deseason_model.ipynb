# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from catboost import CatBoostRegressor, EShapCalcType, EFeaturesSelectionAlgorithm
from statsmodels.tsa.seasonal import STL

import tqdm
# Out:
# 2024-11-28 21:57:17.753339: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def feature_differencing(time_feature, lag):
    diff_feat = time_feature[:-lag]
    diff_feat = np.append(diff_feat.values[:lag], diff_feat)
    return diff_feat
    
    
def add_features(data, time_col):
    data['hour'] = pd.to_datetime(data[time_col]).dt.hour
    data['minute'] = pd.to_datetime(data[time_col]).dt.minute
    
    return data


def time_decompose(data_col, period, season):
    stl = STL(data_col.fillna(data_col.interpolate('linear')), period=period, seasonal=season)
    res = stl.fit()
    seasonal_component = res.seasonal
    trend_component = res.trend

    df_deseason = data_col - seasonal_component - trend_component
    df_deseason_imputed = df_deseason.fillna(df_deseason.interpolate('linear'))
    df_imputed = df_deseason_imputed + seasonal_component + trend_component

    return df_imputed, df_deseason, seasonal_component + trend_component


def prepare_dataset(data, features):
    # Mark missing data
    data['date'] = pd.to_datetime(data['DateTime']).dt.date
    data['is_missing'] = data['Power(mW)'].isnull()
    data['gap_group'] = (~data['is_missing']).cumsum()
    gap_counts = (
        data.groupby('gap_group')['is_missing']
        .sum()
        .reset_index(name='missing_count')
    )
    gap_counts = gap_counts[gap_counts['missing_count'] > 0]

    # Drop the date that have large gap
    # group_lst = gap_counts[gap_counts['missing_count'] > 60]['gap_group'].values
    # missing_date_lst = data[data['gap_group'].isin(group_lst)]['date'].unique()
    # data = data[~data['date'].isin(missing_date_lst)]

    # Impute use decomposition
    for feat in features:
        data[feat], data[f'{feat}_deseason'], data[f'{feat}_season_trend'] = time_decompose(data[feat], 60*30, 15)

    # # Get the complete day only
    # data['date'] = pd.to_datetime(data['DateTime']).dt.date
    # record_counts = data.groupby('date').size()
    # data = data[data['date'].isin(list(record_counts[record_counts == 60].index))]
    data['power_lag1'] = feature_differencing(data['Power(mW)_log_deseason'], 1)
    # train_set['power_lag60'] = feature_differencing(train_set['Power(mW)'], 60)
    data['power_lag2'] = feature_differencing(data['Power(mW)_log_deseason'], 2)
    data['power_lag3'] = feature_differencing(data['Power(mW)_log_deseason'], 3)
    data['power_lag4'] = feature_differencing(data['Power(mW)_log_deseason'], 4)
    data['power_lag5'] = feature_differencing(data['Power(mW)_log_deseason'], 5)

    # get train data and input for test
    hour_dt = pd.to_datetime(data["DateTime"]).dt.time
    data_late = data[(hour_dt >= pd.to_datetime("07:00").time()) & 
                        (hour_dt < pd.to_datetime("17:00").time())]
    
    data_early = data[(hour_dt >= pd.to_datetime("07:00").time()) & 
                        (hour_dt < pd.to_datetime("09:00").time())]
    
    data_to_predict = data_late[data_late['to_predict'] == 1]
    # data_to_predict = data_late
    print(data_to_predict.shape)
    # data_to_predict = data_late

    # drop date with missing value 
    record_counts = data_late.groupby('date')['is_missing'].sum()
    data_late = data_late[data_late['date'].isin(list(record_counts[record_counts == 0].index))]

    record_counts = data_early.groupby('date')['is_missing'].sum()
    data_early = data_early[data_early['date'].isin(list(record_counts[record_counts == 0].index))]
    
    return data_late, data_early, data_to_predict


def scale_min_max(fit_data):
    """
    train_set, test_set: numpy array
    """
    minmax_scaler = MinMaxScaler().fit(fit_data)
    data_scaled = minmax_scaler.transform(fit_data)

    return data_scaled, minmax_scaler


def train_model(train_set):
    train_set = add_features(train_set, 'DateTime')
    features = ['hour', 'minute', 'WindSpeed(m/s)_deseason', 'Pressure(hpa)_deseason',
                'Temperature(°C)_deseason',
                'Humidity(%)_deseason','Sunlight(Lux)_deseason', 
                'power_lag1', 
                'power_lag2', 'power_lag3', 'power_lag4', 'power_lag5',
                'Power(mW)_log_deseason']
    X_features = features[:-1]
    
    train_imputed = train_set[features]
    train_scaled, minmax_scaler = scale_min_max(train_imputed[X_features])

    ## CatBoost

    y_train = train_imputed[['Power(mW)_log_deseason']]
    y_train_scaled, y_scaler = scale_min_max(y_train)
    cat_params = dict(iterations=7000,
                      learning_rate=0.01,
                      depth=11,
                      l2_leaf_reg=30,
                      bootstrap_type='Bernoulli',
                      subsample=0.66,
                      loss_function='MAE',
                      eval_metric = 'MAE',
                      metric_period=100,
                      od_type='Iter',
                      od_wait=30,
                      task_type='GPU',
                      allow_writing_files=False,
                      )

    # Train a LightGBM model for the current fold
    cat_model = CatBoostRegressor(**cat_params)
    cat_model.fit(
        train_scaled,
        y_train_scaled,
        early_stopping_rounds=100
    )
    
    return minmax_scaler, cat_model, y_scaler


def predict_power(test_set, to_predict_data, cat_model, minmax_scaler):
    # date_lst = to_predict_data['date'].unique()
    test_set = add_features(test_set, 'DateTime')
    features = ['hour', 'minute', 'WindSpeed(m/s)_deseason', 'Pressure(hpa)_deseason',
                'Temperature(°C)_deseason',
                'Humidity(%)_deseason','Sunlight(Lux)_deseason', 
                'power_lag1', 
                'power_lag2', 'power_lag3', 'power_lag4', 'power_lag5', 
                'Power(mW)_log_deseason']
    # features = ['Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)', 'Power(mW)']
    X_features = features[:-1]
    
    # get log
#     test_set[features[1:]] = np.log(test_set[features[1:]] + 1)
    
    test_imputed = test_set[features]
    test_scaled = minmax_scaler.transform(test_imputed[X_features])
    # X_test_pred = lstm_predict(lstm_regressor, forecast_num, look_back_num, test_scaled, to_predict_data)
    X_test_pred = test_scaled

    y_pred = cat_model.predict(X_test_pred).reshape(to_predict_data.shape[0])
    # y_pred = np.exp(y_pred) - 1
#     y_test = np.exp(y_test) - 1

    return X_test_pred, y_pred


if __name__ == '__main__':
    features = ['WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Power(mW)_log']
    location_lst = range(1, 18, 1)
    look_back_num = 12
    forecast_num = 48
    data_dir = os.getcwd()

    all_predictions = pd.DataFrame(columns = ["serial", "y_pred"])
    for loc in location_lst:
        print(loc, "----------------------------------------------------------------------------------------------------")
        data = pd.read_csv(data_dir + f'/data/add_lag_diff/loc_{loc}.csv')
        data_late, data_early, data_to_predict = prepare_dataset(data, features)

        # data_late_train, data_late_test = data_late.reset_index().loc[:5500, ], data_late.reset_index().loc[5500:, ]
        minmax_scaler, cat_model, y_scaler = train_model(data_late)
        X_test_pred, y_pred = predict_power(data_to_predict, data_to_predict,  
                                            cat_model=cat_model, minmax_scaler=minmax_scaler)
        y_pred_norm = y_scaler.inverse_transform(y_pred.reshape(-1, 1)).reshape(-1)
        y_pred_norm = y_pred_norm + data_to_predict["Power(mW)_log_season_trend"]
        y_pred_norm = np.exp(y_pred_norm) - 1

        df = pd.DataFrame(columns = ["serial", "y_pred"])
        df['serial'] = data_to_predict['Serial']
        # df['y_pred'] = (y_pred_norm + data_to_predict['Power(mW)_log_season_comp']).values
        df['y_pred'] = y_pred_norm

        all_predictions = pd.concat([all_predictions, df])

    output = pd.read_csv("upload(no answer).csv")
    output = output.merge(all_predictions, left_on='序號', right_on='serial')
    output['答案'] = output['y_pred']
    output[['序號', '答案']].to_csv('output_stl_deseason.csv', index=False)
# Out:
# 1 ----------------------------------------------------------------------------------------------------
# (1152, 96)
# 0:	learn: 0.1199812	total: 168ms	remaining: 19m 33s
# 100:	learn: 0.0286924	total: 12.1s	remaining: 13m 47s
# 200:	learn: 0.0260486	total: 22.1s	remaining: 12m 29s
# 300:	learn: 0.0247021	total: 24.3s	remaining: 9m 1s
# 400:	learn: 0.0234351	total: 26.5s	remaining: 7m 16s
# 500:	learn: 0.0222145	total: 28.5s	remaining: 6m 9s
# 600:	learn: 0.0211932	total: 30.6s	remaining: 5m 26s
# 700:	learn: 0.0202462	total: 33s	remaining: 4m 56s
# 800:	learn: 0.0192612	total: 35.3s	remaining: 4m 33s
# 900:	learn: 0.0183885	total: 38.1s	remaining: 4m 17s
# 1000:	learn: 0.0173286	total: 44.4s	remaining: 4m 26s
# 1100:	learn: 0.0162517	total: 48.7s	remaining: 4m 20s
# 1200:	learn: 0.0152310	total: 54s	remaining: 4m 20s
# 1300:	learn: 0.0142895	total: 58.8s	remaining: 4m 17s
# 1400:	learn: 0.0133657	total: 1m 3s	remaining: 4m 14s
# 1500:	learn: 0.0126123	total: 1m 8s	remaining: 4m 11s
# 1600:	learn: 0.0118466	total: 1m 14s	remaining: 4m 12s
# 1700:	learn: 0.0111521	total: 1m 20s	remaining: 4m 10s
# 1800:	learn: 0.0105048	total: 1m 25s	remaining: 4m 6s
# 1900:	learn: 0.0099340	total: 1m 30s	remaining: 4m 2s
# 2000:	learn: 0.0093860	total: 1m 35s	remaining: 3m 57s
# 2100:	learn: 0.0088748	total: 1m 40s	remaining: 3m 54s
# 2200:	learn: 0.0083694	total: 1m 52s	remaining: 4m 6s
# 2300:	learn: 0.0078760	total: 2m 3s	remaining: 4m 12s
# 2400:	learn: 0.0074667	total: 2m 9s	remaining: 4m 8s
# 2500:	learn: 0.0070593	total: 2m 14s	remaining: 4m 1s
# 2600:	learn: 0.0067059	total: 2m 19s	remaining: 3m 56s
# 2700:	learn: 0.0063427	total: 2m 26s	remaining: 3m 53s
# 2800:	learn: 0.0059866	total: 2m 31s	remaining: 3m 47s
# 2900:	learn: 0.0057203	total: 2m 36s	remaining: 3m 40s
# 3000:	learn: 0.0054487	total: 2m 41s	remaining: 3m 35s
# 3100:	learn: 0.0053024	total: 2m 46s	remaining: 3m 29s
# 3200:	learn: 0.0050505	total: 2m 51s	remaining: 3m 23s
# 3300:	learn: 0.0048478	total: 2m 56s	remaining: 3m 17s
# 3400:	learn: 0.0046487	total: 3m 2s	remaining: 3m 13s
# 3500:	learn: 0.0044856	total: 3m 12s	remaining: 3m 11s
# 3600:	learn: 0.0043201	total: 3m 17s	remaining: 3m 6s
# 3700:	learn: 0.0041591	total: 3m 22s	remaining: 3m
# 3800:	learn: 0.0039689	total: 3m 27s	remaining: 2m 54s
# 3900:	learn: 0.0038271	total: 3m 33s	remaining: 2m 49s
# 4000:	learn: 0.0037326	total: 3m 38s	remaining: 2m 43s
# 4100:	learn: 0.0036163	total: 3m 44s	remaining: 2m 38s
# 4200:	learn: 0.0034731	total: 3m 49s	remaining: 2m 32s
# 4300:	learn: 0.0033893	total: 3m 54s	remaining: 2m 26s
# 4400:	learn: 0.0033250	total: 3m 59s	remaining: 2m 21s
# 4500:	learn: 0.0032044	total: 4m 4s	remaining: 2m 15s
# 4600:	learn: 0.0031520	total: 4m 8s	remaining: 2m 9s
# 4700:	learn: 0.0030144	total: 4m 13s	remaining: 2m 4s
# 4800:	learn: 0.0029909	total: 4m 18s	remaining: 1m 58s
# 4900:	learn: 0.0028515	total: 4m 23s	remaining: 1m 52s
# 5000:	learn: 0.0028122	total: 4m 28s	remaining: 1m 47s
# 5100:	learn: 0.0027879	total: 4m 33s	remaining: 1m 41s
# 5200:	learn: 0.0027383	total: 4m 38s	remaining: 1m 36s
# 5300:	learn: 0.0026456	total: 4m 43s	remaining: 1m 30s
# 5400:	learn: 0.0025568	total: 4m 48s	remaining: 1m 25s
# 5500:	learn: 0.0025221	total: 4m 53s	remaining: 1m 19s
# 5600:	learn: 0.0024664	total: 4m 58s	remaining: 1m 14s
# 5700:	learn: 0.0024551	total: 5m 3s	remaining: 1m 9s
# 5800:	learn: 0.0024095	total: 5m 8s	remaining: 1m 3s
# 5900:	learn: 0.0023557	total: 5m 13s	remaining: 58.5s
# 6000:	learn: 0.0022647	total: 5m 19s	remaining: 53.3s
# 6100:	learn: 0.0022619	total: 5m 24s	remaining: 47.9s
# 6200:	learn: 0.0022138	total: 5m 29s	remaining: 42.5s
# 6300:	learn: 0.0022248	total: 5m 34s	remaining: 37.1s
# 6400:	learn: 0.0021223	total: 5m 39s	remaining: 31.8s
# 6500:	learn: 0.0021297	total: 5m 44s	remaining: 26.5s
# 6600:	learn: 0.0021488	total: 5m 49s	remaining: 21.1s
# 6700:	learn: 0.0020617	total: 5m 54s	remaining: 15.8s
# 6800:	learn: 0.0020654	total: 6m	remaining: 10.5s
# 6900:	learn: 0.0021128	total: 6m 4s	remaining: 5.24s
# 6999:	learn: 0.0020233	total: 6m 9s	remaining: 0us
# 2 ----------------------------------------------------------------------------------------------------
# (432, 96)
# 0:	learn: 0.1425420	total: 11.2ms	remaining: 1m 18s
# 100:	learn: 0.0266131	total: 1.97s	remaining: 2m 14s
# 200:	learn: 0.0239908	total: 4.52s	remaining: 2m 32s
# 300:	learn: 0.0225263	total: 6.55s	remaining: 2m 25s
# 400:	learn: 0.0213299	total: 8.75s	remaining: 2m 24s
# 500:	learn: 0.0202746	total: 10.8s	remaining: 2m 20s
# 600:	learn: 0.0192136	total: 12.9s	remaining: 2m 17s
# 700:	learn: 0.0180238	total: 15.5s	remaining: 2m 18s
# 800:	learn: 0.0170364	total: 17.9s	remaining: 2m 18s
# 900:	learn: 0.0159498	total: 20.8s	remaining: 2m 20s
# 1000:	learn: 0.0147827	total: 24.7s	remaining: 2m 27s
# 1100:	learn: 0.0136960	total: 29.4s	remaining: 2m 37s
# 1200:	learn: 0.0126488	total: 34.2s	remaining: 2m 45s
# 1300:	learn: 0.0117956	total: 39.1s	remaining: 2m 51s
# 1400:	learn: 0.0109891	total: 44s	remaining: 2m 55s
# 1500:	learn: 0.0103212	total: 48.8s	remaining: 2m 58s
# 1600:	learn: 0.0097129	total: 53.7s	remaining: 3m
# 1700:	learn: 0.0090452	total: 58.5s	remaining: 3m 2s
# 1800:	learn: 0.0084935	total: 1m 3s	remaining: 3m 3s
# 1900:	learn: 0.0079330	total: 1m 8s	remaining: 3m 3s
# 2000:	learn: 0.0074927	total: 1m 13s	remaining: 3m 2s
# 2100:	learn: 0.0070617	total: 1m 17s	remaining: 3m 1s
# 2200:	learn: 0.0066465	total: 1m 22s	remaining: 3m
# 2300:	learn: 0.0062412	total: 1m 27s	remaining: 2m 59s
# 2400:	learn: 0.0059542	total: 1m 32s	remaining: 2m 57s
# 2500:	learn: 0.0056398	total: 1m 37s	remaining: 2m 55s
# 2600:	learn: 0.0053630	total: 1m 42s	remaining: 2m 53s
# 2700:	learn: 0.0051954	total: 1m 47s	remaining: 2m 50s
# 2800:	learn: 0.0048817	total: 1m 52s	remaining: 2m 48s
# 2900:	learn: 0.0046721	total: 1m 57s	remaining: 2m 45s
# 3000:	learn: 0.0044518	total: 2m 2s	remaining: 2m 42s
# 3100:	learn: 0.0042901	total: 2m 6s	remaining: 2m 39s
# 3200:	learn: 0.0041131	total: 2m 11s	remaining: 2m 36s
# 3300:	learn: 0.0039451	total: 2m 16s	remaining: 2m 33s
# 3400:	learn: 0.0038171	total: 2m 21s	remaining: 2m 29s
# 3500:	learn: 0.0036371	total: 2m 26s	remaining: 2m 26s
# 3600:	learn: 0.0035297	total: 2m 31s	remaining: 2m 22s
# 3700:	learn: 0.0034100	total: 2m 36s	remaining: 2m 19s
# 3800:	learn: 0.0033007	total: 2m 41s	remaining: 2m 15s
# 3900:	learn: 0.0031990	total: 2m 46s	remaining: 2m 11s
# 4000:	learn: 0.0030513	total: 2m 50s	remaining: 2m 8s
# 4100:	learn: 0.0030589	total: 2m 55s	remaining: 2m 4s
# 4200:	learn: 0.0028760	total: 3m	remaining: 2m
# 4300:	learn: 0.0028241	total: 3m 5s	remaining: 1m 56s
# 4400:	learn: 0.0027950	total: 3m 10s	remaining: 1m 52s
# 4500:	learn: 0.0027540	total: 3m 15s	remaining: 1m 48s
# 4600:	learn: 0.0026937	total: 3m 20s	remaining: 1m 44s
# 4700:	learn: 0.0026227	total: 3m 25s	remaining: 1m 40s
# 4800:	learn: 0.0025311	total: 3m 30s	remaining: 1m 36s
# 4900:	learn: 0.0024490	total: 3m 35s	remaining: 1m 32s
# 5000:	learn: 0.0024124	total: 3m 40s	remaining: 1m 27s
# 5100:	learn: 0.0024236	total: 3m 44s	remaining: 1m 23s
# 5200:	learn: 0.0023794	total: 3m 49s	remaining: 1m 19s
# 5300:	learn: 0.0023480	total: 3m 54s	remaining: 1m 15s
# 5400:	learn: 0.0022501	total: 3m 59s	remaining: 1m 10s
# 5500:	learn: 0.0022259	total: 4m 4s	remaining: 1m 6s
# 5600:	learn: 0.0022031	total: 4m 9s	remaining: 1m 2s
# 5700:	learn: 0.0021637	total: 4m 14s	remaining: 57.9s
# 5800:	learn: 0.0021329	total: 4m 19s	remaining: 53.6s
# 5900:	learn: 0.0021715	total: 4m 24s	remaining: 49.2s
# 6000:	learn: 0.0020560	total: 4m 29s	remaining: 44.8s
# 6100:	learn: 0.0020557	total: 4m 33s	remaining: 40.4s
# 6200:	learn: 0.0020804	total: 4m 38s	remaining: 35.9s
# 6300:	learn: 0.0020186	total: 4m 43s	remaining: 31.5s
# 6400:	learn: 0.0020185	total: 4m 48s	remaining: 27s
# 6500:	learn: 0.0019807	total: 4m 53s	remaining: 22.5s
# 6600:	learn: 0.0019817	total: 4m 58s	remaining: 18s
# 6700:	learn: 0.0019360	total: 5m 3s	remaining: 13.5s
# 6800:	learn: 0.0019193	total: 5m 8s	remaining: 9.02s
# 6900:	learn: 0.0018768	total: 5m 13s	remaining: 4.49s
# 6999:	learn: 0.0018563	total: 5m 17s	remaining: 0us
# 3 ----------------------------------------------------------------------------------------------------
# (288, 96)
# 0:	learn: 0.1174150	total: 32ms	remaining: 3m 43s
# 100:	learn: 0.0295240	total: 1.65s	remaining: 1m 52s
# 200:	learn: 0.0259316	total: 3.88s	remaining: 2m 11s
# 300:	learn: 0.0238310	total: 6.22s	remaining: 2m 18s
# 400:	learn: 0.0222621	total: 8.44s	remaining: 2m 18s
# 500:	learn: 0.0208383	total: 10.8s	remaining: 2m 19s
# 600:	learn: 0.0192727	total: 13.4s	remaining: 2m 22s
# 700:	learn: 0.0176638	total: 16.3s	remaining: 2m 26s
# 800:	learn: 0.0164539	total: 19s	remaining: 2m 26s
# 900:	learn: 0.0150590	total: 22.1s	remaining: 2m 29s
# 1000:	learn: 0.0139038	total: 26.2s	remaining: 2m 37s
# 1100:	learn: 0.0128445	total: 30.8s	remaining: 2m 45s
# 1200:	learn: 0.0117268	total: 35.7s	remaining: 2m 52s
# 1300:	learn: 0.0107430	total: 40.6s	remaining: 2m 57s
# 1400:	learn: 0.0098888	total: 45.5s	remaining: 3m 1s
# 1500:	learn: 0.0091364	total: 50.4s	remaining: 3m 4s
# 1600:	learn: 0.0084674	total: 55.3s	remaining: 3m 6s
# 1700:	learn: 0.0078617	total: 1m	remaining: 3m 7s
# 1800:	learn: 0.0073203	total: 1m 5s	remaining: 3m 7s
# 1900:	learn: 0.0068614	total: 1m 9s	remaining: 3m 7s
# 2000:	learn: 0.0063672	total: 1m 14s	remaining: 3m 6s
# 2100:	learn: 0.0059309	total: 1m 19s	remaining: 3m 5s
# 2200:	learn: 0.0055193	total: 1m 24s	remaining: 3m 4s
# 2300:	learn: 0.0051942	total: 1m 29s	remaining: 3m 2s
# 2400:	learn: 0.0048469	total: 1m 34s	remaining: 3m
# 2500:	learn: 0.0045261	total: 1m 39s	remaining: 2m 58s
# 2600:	learn: 0.0042982	total: 1m 43s	remaining: 2m 55s
# 2700:	learn: 0.0041193	total: 1m 48s	remaining: 2m 53s
# 2800:	learn: 0.0038570	total: 1m 53s	remaining: 2m 50s
# 2900:	learn: 0.0036135	total: 1m 58s	remaining: 2m 47s
# 3000:	learn: 0.0034750	total: 2m 3s	remaining: 2m 44s
# 3100:	learn: 0.0033209	total: 2m 8s	remaining: 2m 41s
# 3200:	learn: 0.0031120	total: 2m 13s	remaining: 2m 38s
# 3300:	learn: 0.0029147	total: 2m 18s	remaining: 2m 34s
# 3400:	learn: 0.0028383	total: 2m 22s	remaining: 2m 31s
# 3500:	learn: 0.0027467	total: 2m 27s	remaining: 2m 27s
# 3600:	learn: 0.0026086	total: 2m 32s	remaining: 2m 24s
# 3700:	learn: 0.0025629	total: 2m 37s	remaining: 2m 20s
# 3800:	learn: 0.0024551	total: 2m 42s	remaining: 2m 16s
# 3900:	learn: 0.0024632	total: 2m 47s	remaining: 2m 12s
# 4000:	learn: 0.0023757	total: 2m 52s	remaining: 2m 9s
# 4100:	learn: 0.0023165	total: 2m 57s	remaining: 2m 5s
# 4200:	learn: 0.0022093	total: 3m 2s	remaining: 2m 1s
# 4300:	learn: 0.0022102	total: 3m 7s	remaining: 1m 57s
# 4400:	learn: 0.0021063	total: 3m 12s	remaining: 1m 53s
# 4500:	learn: 0.0020987	total: 3m 16s	remaining: 1m 49s
# 4600:	learn: 0.0020333	total: 3m 21s	remaining: 1m 45s
# 4700:	learn: 0.0020331	total: 3m 26s	remaining: 1m 41s
# 4800:	learn: 0.0019896	total: 3m 31s	remaining: 1m 36s
# 4900:	learn: 0.0019699	total: 3m 36s	remaining: 1m 32s
# 5000:	learn: 0.0019146	total: 3m 41s	remaining: 1m 28s
# 5100:	learn: 0.0018808	total: 3m 45s	remaining: 1m 24s
# 5200:	learn: 0.0018978	total: 3m 50s	remaining: 1m 19s
# 5300:	learn: 0.0018244	total: 3m 55s	remaining: 1m 15s
# 5400:	learn: 0.0018086	total: 4m	remaining: 1m 11s
# 5500:	learn: 0.0017810	total: 4m 5s	remaining: 1m 6s
# 5600:	learn: 0.0018327	total: 4m 10s	remaining: 1m 2s
# 5700:	learn: 0.0017335	total: 4m 15s	remaining: 58.2s
# 5800:	learn: 0.0017625	total: 4m 20s	remaining: 53.8s
# 5900:	learn: 0.0017051	total: 4m 25s	remaining: 49.4s
# 6000:	learn: 0.0016443	total: 4m 29s	remaining: 44.9s
# 6100:	learn: 0.0017002	total: 4m 34s	remaining: 40.5s
# 6200:	learn: 0.0017161	total: 4m 39s	remaining: 36s
# 6300:	learn: 0.0017039	total: 4m 44s	remaining: 31.6s
# 6400:	learn: 0.0016583	total: 4m 49s	remaining: 27.1s
# 6500:	learn: 0.0016080	total: 4m 54s	remaining: 22.6s
# 6600:	learn: 0.0016205	total: 4m 59s	remaining: 18.1s
# 6700:	learn: 0.0016240	total: 5m 4s	remaining: 13.6s
# 6800:	learn: 0.0016274	total: 5m 9s	remaining: 9.04s
# 6900:	learn: 0.0016469	total: 5m 13s	remaining: 4.5s
# 6999:	learn: 0.0016198	total: 5m 18s	remaining: 0us
# 4 ----------------------------------------------------------------------------------------------------
# (384, 96)
# 0:	learn: 0.0999169	total: 9.48ms	remaining: 1m 6s
# 100:	learn: 0.0289332	total: 1.62s	remaining: 1m 50s
# 200:	learn: 0.0254720	total: 3.6s	remaining: 2m 1s
# 300:	learn: 0.0235596	total: 5.57s	remaining: 2m 3s
# 400:	learn: 0.0219101	total: 7.98s	remaining: 2m 11s
# 500:	learn: 0.0205369	total: 10.2s	remaining: 2m 12s
# 600:	learn: 0.0192390	total: 12.5s	remaining: 2m 13s
# 700:	learn: 0.0178684	total: 15s	remaining: 2m 14s
# 800:	learn: 0.0166392	total: 17.7s	remaining: 2m 16s
# 900:	learn: 0.0155091	total: 20.6s	remaining: 2m 19s
# 1000:	learn: 0.0143352	total: 24.4s	remaining: 2m 26s
# 1100:	learn: 0.0131936	total: 28.9s	remaining: 2m 35s
# 1200:	learn: 0.0120761	total: 33.8s	remaining: 2m 43s
# 1300:	learn: 0.0110925	total: 38.8s	remaining: 2m 49s
# 1400:	learn: 0.0101799	total: 43.6s	remaining: 2m 54s
# 1500:	learn: 0.0093511	total: 48.5s	remaining: 2m 57s
# 1600:	learn: 0.0086350	total: 53.4s	remaining: 3m
# 1700:	learn: 0.0079340	total: 58.3s	remaining: 3m 1s
# 1800:	learn: 0.0072977	total: 1m 3s	remaining: 3m 2s
# 1900:	learn: 0.0067058	total: 1m 8s	remaining: 3m 3s
# 2000:	learn: 0.0062647	total: 1m 13s	remaining: 3m 2s
# 2100:	learn: 0.0058250	total: 1m 18s	remaining: 3m 1s
# 2200:	learn: 0.0054445	total: 1m 22s	remaining: 3m
# 2300:	learn: 0.0050839	total: 1m 27s	remaining: 2m 59s
# 2400:	learn: 0.0047682	total: 1m 32s	remaining: 2m 57s
# 2500:	learn: 0.0044722	total: 1m 37s	remaining: 2m 55s
# 2600:	learn: 0.0042182	total: 1m 42s	remaining: 2m 53s
# 2700:	learn: 0.0040169	total: 1m 47s	remaining: 2m 51s
# 2800:	learn: 0.0038086	total: 1m 52s	remaining: 2m 48s
# 2900:	learn: 0.0036312	total: 1m 57s	remaining: 2m 45s
# 3000:	learn: 0.0034163	total: 2m 2s	remaining: 2m 42s
# 3100:	learn: 0.0032595	total: 2m 7s	remaining: 2m 39s
# 3200:	learn: 0.0031277	total: 2m 11s	remaining: 2m 36s
# 3300:	learn: 0.0029565	total: 2m 16s	remaining: 2m 33s
# 3400:	learn: 0.0029228	total: 2m 21s	remaining: 2m 30s
# 3500:	learn: 0.0027933	total: 2m 26s	remaining: 2m 26s
# 3600:	learn: 0.0027277	total: 2m 31s	remaining: 2m 23s
# 3700:	learn: 0.0026117	total: 2m 36s	remaining: 2m 19s
# 3800:	learn: 0.0025676	total: 2m 41s	remaining: 2m 15s
# 3900:	learn: 0.0024854	total: 2m 46s	remaining: 2m 12s
# 4000:	learn: 0.0023673	total: 2m 51s	remaining: 2m 8s
# 4100:	learn: 0.0023204	total: 2m 56s	remaining: 2m 4s
# 4200:	learn: 0.0022929	total: 3m 1s	remaining: 2m
# 4300:	learn: 0.0022751	total: 3m 6s	remaining: 1m 56s
# 4400:	learn: 0.0021669	total: 3m 11s	remaining: 1m 52s
# 4500:	learn: 0.0021937	total: 3m 15s	remaining: 1m 48s
# 4600:	learn: 0.0020982	total: 3m 20s	remaining: 1m 44s
# 4700:	learn: 0.0021395	total: 3m 25s	remaining: 1m 40s
# 4800:	learn: 0.0020398	total: 3m 30s	remaining: 1m 36s
# 4900:	learn: 0.0019537	total: 3m 35s	remaining: 1m 32s
# 5000:	learn: 0.0019561	total: 3m 40s	remaining: 1m 28s
# 5100:	learn: 0.0019603	total: 3m 45s	remaining: 1m 23s
# 5200:	learn: 0.0019122	total: 3m 50s	remaining: 1m 19s
# 5300:	learn: 0.0018680	total: 3m 54s	remaining: 1m 15s
# 5400:	learn: 0.0018444	total: 3m 59s	remaining: 1m 10s
# 5500:	learn: 0.0018545	total: 4m 4s	remaining: 1m 6s
# 5600:	learn: 0.0019054	total: 4m 9s	remaining: 1m 2s
# 5700:	learn: 0.0018651	total: 4m 14s	remaining: 58s
# 5800:	learn: 0.0017383	total: 4m 19s	remaining: 53.6s
# 5900:	learn: 0.0017519	total: 4m 24s	remaining: 49.2s
# 6000:	learn: 0.0017478	total: 4m 29s	remaining: 44.8s
# 6100:	learn: 0.0017706	total: 4m 34s	remaining: 40.4s
# 6200:	learn: 0.0017917	total: 4m 38s	remaining: 35.9s
# 6300:	learn: 0.0016832	total: 4m 43s	remaining: 31.5s
# 6400:	learn: 0.0017273	total: 4m 48s	remaining: 27s
# 6500:	learn: 0.0016507	total: 4m 53s	remaining: 22.5s
# 6600:	learn: 0.0016704	total: 4m 58s	remaining: 18s
# 6700:	learn: 0.0016886	total: 5m 3s	remaining: 13.5s
# 6800:	learn: 0.0016517	total: 5m 8s	remaining: 9.02s
# 6900:	learn: 0.0016199	total: 5m 13s	remaining: 4.49s
# 6999:	learn: 0.0016213	total: 5m 17s	remaining: 0us
# 5 ----------------------------------------------------------------------------------------------------
# (288, 96)
# 0:	learn: 0.0711104	total: 27.4ms	remaining: 3m 12s
# 100:	learn: 0.0205673	total: 2.16s	remaining: 2m 27s
# 200:	learn: 0.0165884	total: 4.37s	remaining: 2m 27s
# 300:	learn: 0.0143202	total: 6.8s	remaining: 2m 31s
# 400:	learn: 0.0120253	total: 9.58s	remaining: 2m 37s
# 500:	learn: 0.0100389	total: 12.3s	remaining: 2m 39s
# 600:	learn: 0.0086538	total: 15s	remaining: 2m 40s
# 700:	learn: 0.0075683	total: 17.6s	remaining: 2m 38s
# 800:	learn: 0.0065320	total: 20.7s	remaining: 2m 40s
# 900:	learn: 0.0056378	total: 24.2s	remaining: 2m 43s
# 1000:	learn: 0.0047756	total: 28.7s	remaining: 2m 51s
# 1100:	learn: 0.0041413	total: 33.4s	remaining: 2m 58s
# 1200:	learn: 0.0035855	total: 38.3s	remaining: 3m 4s
# 1300:	learn: 0.0032058	total: 43.2s	remaining: 3m 9s
# 1400:	learn: 0.0029060	total: 48.1s	remaining: 3m 12s
# 1500:	learn: 0.0026186	total: 53s	remaining: 3m 14s
# 1600:	learn: 0.0023879	total: 57.9s	remaining: 3m 15s
# 1700:	learn: 0.0021742	total: 1m 2s	remaining: 3m 15s
# 1800:	learn: 0.0020496	total: 1m 7s	remaining: 3m 15s
# 1900:	learn: 0.0019636	total: 1m 12s	remaining: 3m 14s
# 2000:	learn: 0.0018702	total: 1m 17s	remaining: 3m 13s
# 2100:	learn: 0.0017949	total: 1m 22s	remaining: 3m 11s
# 2200:	learn: 0.0017067	total: 1m 27s	remaining: 3m 10s
# 2300:	learn: 0.0017369	total: 1m 32s	remaining: 3m 7s
# 2400:	learn: 0.0017064	total: 1m 36s	remaining: 3m 5s
# 2500:	learn: 0.0016532	total: 1m 41s	remaining: 3m 3s
# 2600:	learn: 0.0017071	total: 1m 46s	remaining: 3m
# 2700:	learn: 0.0015691	total: 1m 51s	remaining: 2m 57s
# 2800:	learn: 0.0015676	total: 1m 56s	remaining: 2m 54s
# 2900:	learn: 0.0016016	total: 2m 1s	remaining: 2m 51s
# 3000:	learn: 0.0015693	total: 2m 6s	remaining: 2m 48s
# 3100:	learn: 0.0015719	total: 2m 10s	remaining: 2m 44s
# 3200:	learn: 0.0015342	total: 2m 15s	remaining: 2m 41s
# 3300:	learn: 0.0015144	total: 2m 20s	remaining: 2m 37s
# 3400:	learn: 0.0014710	total: 2m 25s	remaining: 2m 33s
# 3500:	learn: 0.0015309	total: 2m 30s	remaining: 2m 30s
# 3600:	learn: 0.0014955	total: 2m 35s	remaining: 2m 26s
# 3700:	learn: 0.0015427	total: 2m 40s	remaining: 2m 22s
# 3800:	learn: 0.0014450	total: 2m 44s	remaining: 2m 18s
# 3900:	learn: 0.0014698	total: 2m 49s	remaining: 2m 14s
# 4000:	learn: 0.0014828	total: 2m 54s	remaining: 2m 10s
# 4100:	learn: 0.0015241	total: 2m 59s	remaining: 2m 6s
# 4200:	learn: 0.0015242	total: 3m 4s	remaining: 2m 2s
# 4300:	learn: 0.0015488	total: 3m 9s	remaining: 1m 58s
# 4400:	learn: 0.0014739	total: 3m 14s	remaining: 1m 54s
# 4500:	learn: 0.0015314	total: 3m 18s	remaining: 1m 50s
# 4600:	learn: 0.0014649	total: 3m 23s	remaining: 1m 46s
# 4700:	learn: 0.0014727	total: 3m 28s	remaining: 1m 42s
# 4800:	learn: 0.0014953	total: 3m 33s	remaining: 1m 37s
# 4900:	learn: 0.0015283	total: 3m 38s	remaining: 1m 33s
# 5000:	learn: 0.0014175	total: 3m 43s	remaining: 1m 29s
# 5100:	learn: 0.0015304	total: 3m 48s	remaining: 1m 24s
# 5200:	learn: 0.0015271	total: 3m 52s	remaining: 1m 20s
# 5300:	learn: 0.0014512	total: 3m 57s	remaining: 1m 16s
# 5400:	learn: 0.0015389	total: 4m 2s	remaining: 1m 11s
# 5500:	learn: 0.0014674	total: 4m 7s	remaining: 1m 7s
# 5600:	learn: 0.0014380	total: 4m 12s	remaining: 1m 3s
# 5700:	learn: 0.0014742	total: 4m 17s	remaining: 58.6s
# 5800:	learn: 0.0014317	total: 4m 22s	remaining: 54.2s
# 5900:	learn: 0.0014520	total: 4m 27s	remaining: 49.7s
# 6000:	learn: 0.0013971	total: 4m 31s	remaining: 45.3s
# 6100:	learn: 0.0014731	total: 4m 36s	remaining: 40.8s
# 6200:	learn: 0.0015031	total: 4m 41s	remaining: 36.3s
# 6300:	learn: 0.0014618	total: 4m 46s	remaining: 31.8s
# 6400:	learn: 0.0014605	total: 4m 51s	remaining: 27.3s
# 6500:	learn: 0.0014907	total: 4m 56s	remaining: 22.8s
# 6600:	learn: 0.0015187	total: 5m 1s	remaining: 18.2s
# 6700:	learn: 0.0014253	total: 5m 6s	remaining: 13.7s
# 6800:	learn: 0.0014715	total: 5m 11s	remaining: 9.1s
# 6900:	learn: 0.0014688	total: 5m 15s	remaining: 4.53s
# 6999:	learn: 0.0014589	total: 5m 20s	remaining: 0us
# 6 ----------------------------------------------------------------------------------------------------
# (288, 96)
# 0:	learn: 0.0411869	total: 18ms	remaining: 2m 6s
# 100:	learn: 0.0102288	total: 3.3s	remaining: 3m 45s
# 200:	learn: 0.0071329	total: 6.46s	remaining: 3m 38s
# 300:	learn: 0.0055504	total: 9.87s	remaining: 3m 39s
# 400:	learn: 0.0045287	total: 13.2s	remaining: 3m 36s
# 500:	learn: 0.0039778	total: 16.2s	remaining: 3m 30s
# 600:	learn: 0.0035698	total: 19.2s	remaining: 3m 24s
# 700:	learn: 0.0031506	total: 22.7s	remaining: 3m 23s
# 800:	learn: 0.0027405	total: 26.2s	remaining: 3m 22s
# 900:	learn: 0.0025006	total: 29.7s	remaining: 3m 21s
# 1000:	learn: 0.0023431	total: 33.7s	remaining: 3m 22s
# 1100:	learn: 0.0021430	total: 38.5s	remaining: 3m 26s
# 1200:	learn: 0.0020676	total: 43.4s	remaining: 3m 29s
# 1300:	learn: 0.0020218	total: 48.3s	remaining: 3m 31s
# 1400:	learn: 0.0019426	total: 53.2s	remaining: 3m 32s
# 1500:	learn: 0.0018764	total: 58s	remaining: 3m 32s
# 1600:	learn: 0.0017612	total: 1m 2s	remaining: 3m 32s
# 1700:	learn: 0.0017271	total: 1m 7s	remaining: 3m 31s
# 1800:	learn: 0.0016751	total: 1m 12s	remaining: 3m 29s
# 1900:	learn: 0.0017305	total: 1m 17s	remaining: 3m 28s
# 2000:	learn: 0.0016195	total: 1m 22s	remaining: 3m 26s
# 2100:	learn: 0.0016837	total: 1m 27s	remaining: 3m 23s
# 2200:	learn: 0.0016182	total: 1m 32s	remaining: 3m 21s
# 2300:	learn: 0.0016573	total: 1m 37s	remaining: 3m 18s
# 2400:	learn: 0.0015864	total: 1m 42s	remaining: 3m 15s
# 2500:	learn: 0.0015765	total: 1m 46s	remaining: 3m 12s
# 2600:	learn: 0.0016599	total: 1m 51s	remaining: 3m 9s
# 2700:	learn: 0.0015862	total: 1m 56s	remaining: 3m 5s
# 2800:	learn: 0.0015803	total: 2m 1s	remaining: 3m 2s
# 2900:	learn: 0.0015717	total: 2m 6s	remaining: 2m 58s
# 3000:	learn: 0.0015896	total: 2m 11s	remaining: 2m 54s
# 3100:	learn: 0.0015494	total: 2m 16s	remaining: 2m 51s
# 3200:	learn: 0.0015860	total: 2m 20s	remaining: 2m 47s
# 3300:	learn: 0.0015321	total: 2m 25s	remaining: 2m 43s
# 3400:	learn: 0.0015444	total: 2m 30s	remaining: 2m 39s
# 3500:	learn: 0.0015537	total: 2m 35s	remaining: 2m 35s
# 3600:	learn: 0.0015512	total: 2m 40s	remaining: 2m 31s
# 3700:	learn: 0.0015410	total: 2m 45s	remaining: 2m 27s
# 3800:	learn: 0.0014791	total: 2m 50s	remaining: 2m 23s
# 3900:	learn: 0.0015631	total: 2m 55s	remaining: 2m 19s
# 4000:	learn: 0.0015185	total: 3m	remaining: 2m 14s
# 4100:	learn: 0.0015198	total: 3m 4s	remaining: 2m 10s
# 4200:	learn: 0.0015002	total: 3m 9s	remaining: 2m 6s
# 4300:	learn: 0.0015062	total: 3m 14s	remaining: 2m 2s
# 4400:	learn: 0.0014709	total: 3m 19s	remaining: 1m 57s
# 4500:	learn: 0.0014679	total: 3m 24s	remaining: 1m 53s
# 4600:	learn: 0.0015036	total: 3m 29s	remaining: 1m 49s
# 4700:	learn: 0.0014786	total: 3m 34s	remaining: 1m 44s
# 4800:	learn: 0.0015724	total: 3m 39s	remaining: 1m 40s
# 4900:	learn: 0.0014598	total: 3m 44s	remaining: 1m 35s
# 5000:	learn: 0.0014204	total: 3m 48s	remaining: 1m 31s
# 5100:	learn: 0.0014951	total: 3m 53s	remaining: 1m 27s
# 5200:	learn: 0.0015391	total: 3m 58s	remaining: 1m 22s
# 5300:	learn: 0.0015152	total: 4m 3s	remaining: 1m 18s
# 5400:	learn: 0.0015078	total: 4m 8s	remaining: 1m 13s
# 5500:	learn: 0.0014381	total: 4m 13s	remaining: 1m 9s
# 5600:	learn: 0.0014930	total: 4m 18s	remaining: 1m 4s
# 5700:	learn: 0.0015338	total: 4m 23s	remaining: 60s
# 5800:	learn: 0.0014930	total: 4m 28s	remaining: 55.4s
# 5900:	learn: 0.0015293	total: 4m 33s	remaining: 50.8s
# 6000:	learn: 0.0015432	total: 4m 37s	remaining: 46.3s
# 6100:	learn: 0.0015442	total: 4m 42s	remaining: 41.7s
# 6200:	learn: 0.0015685	total: 4m 47s	remaining: 37.1s
# 6300:	learn: 0.0015631	total: 4m 52s	remaining: 32.4s
# 6400:	learn: 0.0015625	total: 4m 57s	remaining: 27.8s
# 6500:	learn: 0.0014847	total: 5m 2s	remaining: 23.2s
# 6600:	learn: 0.0014695	total: 5m 7s	remaining: 18.6s
# 6700:	learn: 0.0014911	total: 5m 12s	remaining: 13.9s
# 6800:	learn: 0.0014601	total: 5m 16s	remaining: 9.27s
# 6900:	learn: 0.0015143	total: 5m 21s	remaining: 4.62s
# 6999:	learn: 0.0015251	total: 5m 26s	remaining: 0us
# 7 ----------------------------------------------------------------------------------------------------
# (336, 96)
# 0:	learn: 0.1110308	total: 9.44ms	remaining: 1m 6s
# 100:	learn: 0.0297479	total: 1.7s	remaining: 1m 56s
# 200:	learn: 0.0250970	total: 4.06s	remaining: 2m 17s
# 300:	learn: 0.0229101	total: 6.38s	remaining: 2m 22s
# 400:	learn: 0.0207040	total: 8.81s	remaining: 2m 25s
# 500:	learn: 0.0188723	total: 11s	remaining: 2m 22s
# 600:	learn: 0.0171258	total: 13.7s	remaining: 2m 25s
# 700:	learn: 0.0156545	total: 16.2s	remaining: 2m 25s
# 800:	learn: 0.0142930	total: 18.9s	remaining: 2m 26s
# 900:	learn: 0.0129109	total: 22.1s	remaining: 2m 29s
# 1000:	learn: 0.0114559	total: 26.3s	remaining: 2m 37s
# 1100:	learn: 0.0101749	total: 30.9s	remaining: 2m 45s
# 1200:	learn: 0.0090585	total: 35.7s	remaining: 2m 52s
# 1300:	learn: 0.0081629	total: 40.6s	remaining: 2m 57s
# 1400:	learn: 0.0073261	total: 45.4s	remaining: 3m 1s
# 1500:	learn: 0.0067038	total: 50.2s	remaining: 3m 4s
# 1600:	learn: 0.0061243	total: 55s	remaining: 3m 5s
# 1700:	learn: 0.0055818	total: 59.9s	remaining: 3m 6s
# 1800:	learn: 0.0051641	total: 1m 4s	remaining: 3m 6s
# 1900:	learn: 0.0047559	total: 1m 9s	remaining: 3m 6s
# 2000:	learn: 0.0043997	total: 1m 14s	remaining: 3m 6s
# 2100:	learn: 0.0040856	total: 1m 19s	remaining: 3m 5s
# 2200:	learn: 0.0038238	total: 1m 24s	remaining: 3m 3s
# 2300:	learn: 0.0036070	total: 1m 29s	remaining: 3m 1s
# 2400:	learn: 0.0033587	total: 1m 33s	remaining: 2m 59s
# 2500:	learn: 0.0031559	total: 1m 38s	remaining: 2m 57s
# 2600:	learn: 0.0030593	total: 1m 43s	remaining: 2m 55s
# 2700:	learn: 0.0028608	total: 1m 48s	remaining: 2m 52s
# 2800:	learn: 0.0027276	total: 1m 53s	remaining: 2m 49s
# 2900:	learn: 0.0025886	total: 1m 58s	remaining: 2m 46s
# 3000:	learn: 0.0025102	total: 2m 3s	remaining: 2m 43s
# 3100:	learn: 0.0024263	total: 2m 7s	remaining: 2m 40s
# 3200:	learn: 0.0023460	total: 2m 12s	remaining: 2m 37s
# 3300:	learn: 0.0021901	total: 2m 17s	remaining: 2m 34s
# 3400:	learn: 0.0021563	total: 2m 22s	remaining: 2m 30s
# 3500:	learn: 0.0020715	total: 2m 27s	remaining: 2m 27s
# 3600:	learn: 0.0019309	total: 2m 32s	remaining: 2m 23s
# 3700:	learn: 0.0019124	total: 2m 37s	remaining: 2m 20s
# 3800:	learn: 0.0018722	total: 2m 41s	remaining: 2m 16s
# 3900:	learn: 0.0019042	total: 2m 46s	remaining: 2m 12s
# 4000:	learn: 0.0018236	total: 2m 51s	remaining: 2m 8s
# 4100:	learn: 0.0018401	total: 2m 56s	remaining: 2m 4s
# 4200:	learn: 0.0017085	total: 3m 1s	remaining: 2m
# 4300:	learn: 0.0016689	total: 3m 6s	remaining: 1m 57s
# 4400:	learn: 0.0017255	total: 3m 11s	remaining: 1m 53s
# 4500:	learn: 0.0017142	total: 3m 16s	remaining: 1m 48s
# 4600:	learn: 0.0016440	total: 3m 21s	remaining: 1m 44s
# 4700:	learn: 0.0016360	total: 3m 25s	remaining: 1m 40s
# 4800:	learn: 0.0015883	total: 3m 30s	remaining: 1m 36s
# 4900:	learn: 0.0016746	total: 3m 35s	remaining: 1m 32s
# 5000:	learn: 0.0015485	total: 3m 40s	remaining: 1m 28s
# 5100:	learn: 0.0015639	total: 3m 45s	remaining: 1m 23s
# 5200:	learn: 0.0015319	total: 3m 50s	remaining: 1m 19s
# 5300:	learn: 0.0016088	total: 3m 54s	remaining: 1m 15s
# 5400:	learn: 0.0015155	total: 3m 59s	remaining: 1m 10s
# 5500:	learn: 0.0015402	total: 4m 4s	remaining: 1m 6s
# 5600:	learn: 0.0015314	total: 4m 9s	remaining: 1m 2s
# 5700:	learn: 0.0015464	total: 4m 14s	remaining: 57.9s
# 5800:	learn: 0.0014709	total: 4m 19s	remaining: 53.6s
# 5900:	learn: 0.0015522	total: 4m 24s	remaining: 49.2s
# 6000:	learn: 0.0015191	total: 4m 28s	remaining: 44.8s
# 6100:	learn: 0.0015535	total: 4m 33s	remaining: 40.3s
# 6200:	learn: 0.0015474	total: 4m 38s	remaining: 35.9s
# 6300:	learn: 0.0015813	total: 4m 43s	remaining: 31.4s
# 6400:	learn: 0.0015257	total: 4m 48s	remaining: 27s
# 6500:	learn: 0.0015316	total: 4m 53s	remaining: 22.5s
# 6600:	learn: 0.0015529	total: 4m 57s	remaining: 18s
# 6700:	learn: 0.0015655	total: 5m 2s	remaining: 13.5s
# 6800:	learn: 0.0014450	total: 5m 7s	remaining: 9s
# 6900:	learn: 0.0015994	total: 5m 12s	remaining: 4.48s
# 6999:	learn: 0.0014961	total: 5m 17s	remaining: 0us
# 8 ----------------------------------------------------------------------------------------------------
# (1440, 96)
# 0:	learn: 0.1091335	total: 20.1ms	remaining: 2m 20s
# 100:	learn: 0.0257184	total: 2.2s	remaining: 2m 30s
# 200:	learn: 0.0238459	total: 4.76s	remaining: 2m 40s
# 300:	learn: 0.0226204	total: 6.85s	remaining: 2m 32s
# 400:	learn: 0.0215217	total: 9.54s	remaining: 2m 36s
# 500:	learn: 0.0205521	total: 11.7s	remaining: 2m 32s
# 600:	learn: 0.0196316	total: 14.3s	remaining: 2m 31s
# 700:	learn: 0.0187766	total: 17.2s	remaining: 2m 34s
# 800:	learn: 0.0178300	total: 20.2s	remaining: 2m 36s
# 900:	learn: 0.0169499	total: 23.4s	remaining: 2m 38s
# 1000:	learn: 0.0160776	total: 27.4s	remaining: 2m 44s
# 1100:	learn: 0.0151479	total: 32.2s	remaining: 2m 52s
# 1200:	learn: 0.0142193	total: 37.8s	remaining: 3m 2s
# 1300:	learn: 0.0133378	total: 43.4s	remaining: 3m 10s
# 1400:	learn: 0.0125592	total: 49.1s	remaining: 3m 16s
# 1500:	learn: 0.0118536	total: 54.7s	remaining: 3m 20s
# 1600:	learn: 0.0111799	total: 1m	remaining: 3m 23s
# 1700:	learn: 0.0105769	total: 1m 6s	remaining: 3m 25s
# 1800:	learn: 0.0099690	total: 1m 11s	remaining: 3m 26s
# 1900:	learn: 0.0094545	total: 1m 17s	remaining: 3m 27s
# 2000:	learn: 0.0089730	total: 1m 22s	remaining: 3m 27s
# 2100:	learn: 0.0085058	total: 1m 28s	remaining: 3m 26s
# 2200:	learn: 0.0081000	total: 1m 34s	remaining: 3m 25s
# 2300:	learn: 0.0077136	total: 1m 39s	remaining: 3m 23s
# 2400:	learn: 0.0073440	total: 1m 45s	remaining: 3m 22s
# 2500:	learn: 0.0070447	total: 1m 51s	remaining: 3m 19s
# 2600:	learn: 0.0067164	total: 1m 56s	remaining: 3m 17s
# 2700:	learn: 0.0064450	total: 2m 2s	remaining: 3m 14s
# 2800:	learn: 0.0061502	total: 2m 8s	remaining: 3m 12s
# 2900:	learn: 0.0058920	total: 2m 13s	remaining: 3m 9s
# 3000:	learn: 0.0056664	total: 2m 19s	remaining: 3m 5s
# 3100:	learn: 0.0054847	total: 2m 25s	remaining: 3m 2s
# 3200:	learn: 0.0052805	total: 2m 30s	remaining: 2m 59s
# 3300:	learn: 0.0050990	total: 2m 36s	remaining: 2m 55s
# 3400:	learn: 0.0049576	total: 2m 42s	remaining: 2m 51s
# 3500:	learn: 0.0047678	total: 2m 47s	remaining: 2m 47s
# 3600:	learn: 0.0045947	total: 2m 53s	remaining: 2m 43s
# 3700:	learn: 0.0044795	total: 2m 59s	remaining: 2m 39s
# 3800:	learn: 0.0043133	total: 3m 4s	remaining: 2m 35s
# 3900:	learn: 0.0042212	total: 3m 10s	remaining: 2m 31s
# 4000:	learn: 0.0040960	total: 3m 16s	remaining: 2m 27s
# 4100:	learn: 0.0040233	total: 3m 21s	remaining: 2m 22s
# 4200:	learn: 0.0039226	total: 3m 27s	remaining: 2m 18s
# 4300:	learn: 0.0038204	total: 3m 33s	remaining: 2m 13s
# 4400:	learn: 0.0037332	total: 3m 38s	remaining: 2m 9s
# 4500:	learn: 0.0036517	total: 3m 44s	remaining: 2m 4s
# 4600:	learn: 0.0035618	total: 3m 50s	remaining: 2m
# 4700:	learn: 0.0034920	total: 3m 55s	remaining: 1m 55s
# 4800:	learn: 0.0033990	total: 4m 1s	remaining: 1m 50s
# 4900:	learn: 0.0033692	total: 4m 7s	remaining: 1m 45s
# 5000:	learn: 0.0032835	total: 4m 12s	remaining: 1m 41s
# 5100:	learn: 0.0032514	total: 4m 18s	remaining: 1m 36s
# 5200:	learn: 0.0031367	total: 4m 24s	remaining: 1m 31s
# 5300:	learn: 0.0031302	total: 4m 29s	remaining: 1m 26s
# 5400:	learn: 0.0030583	total: 4m 35s	remaining: 1m 21s
# 5500:	learn: 0.0029948	total: 4m 41s	remaining: 1m 16s
# 5600:	learn: 0.0029945	total: 4m 46s	remaining: 1m 11s
# 5700:	learn: 0.0029303	total: 4m 52s	remaining: 1m 6s
# 5800:	learn: 0.0028765	total: 4m 58s	remaining: 1m 1s
# 5900:	learn: 0.0029232	total: 5m 3s	remaining: 56.6s
# 6000:	learn: 0.0028156	total: 5m 9s	remaining: 51.5s
# 6100:	learn: 0.0027979	total: 5m 15s	remaining: 46.4s
# 6200:	learn: 0.0027885	total: 5m 20s	remaining: 41.3s
# 6300:	learn: 0.0027479	total: 5m 26s	remaining: 36.2s
# 6400:	learn: 0.0026785	total: 5m 32s	remaining: 31.1s
# 6500:	learn: 0.0026388	total: 5m 37s	remaining: 25.9s
# 6600:	learn: 0.0026748	total: 5m 43s	remaining: 20.8s
# 6700:	learn: 0.0026219	total: 5m 49s	remaining: 15.6s
# 6800:	learn: 0.0026622	total: 5m 54s	remaining: 10.4s
# 6900:	learn: 0.0026069	total: 6m	remaining: 5.17s
# 6999:	learn: 0.0025198	total: 6m 6s	remaining: 0us
# 9 ----------------------------------------------------------------------------------------------------
# (528, 96)
# 0:	learn: 0.1143747	total: 8.49ms	remaining: 59.4s
# 100:	learn: 0.0274375	total: 1.66s	remaining: 1m 53s
# 200:	learn: 0.0251269	total: 3.85s	remaining: 2m 10s
# 300:	learn: 0.0236420	total: 5.94s	remaining: 2m 12s
# 400:	learn: 0.0224902	total: 8.04s	remaining: 2m 12s
# 500:	learn: 0.0212204	total: 10.2s	remaining: 2m 12s
# 600:	learn: 0.0203546	total: 12.3s	remaining: 2m 10s
# 700:	learn: 0.0191768	total: 14.9s	remaining: 2m 14s
# 800:	learn: 0.0181237	total: 17.5s	remaining: 2m 15s
# 900:	learn: 0.0171800	total: 20.1s	remaining: 2m 15s
# 1000:	learn: 0.0160475	total: 23.8s	remaining: 2m 22s
# 1100:	learn: 0.0150238	total: 28.2s	remaining: 2m 31s
# 1200:	learn: 0.0140809	total: 33s	remaining: 2m 39s
# 1300:	learn: 0.0131265	total: 37.9s	remaining: 2m 45s
# 1400:	learn: 0.0122248	total: 42.8s	remaining: 2m 51s
# 1500:	learn: 0.0114144	total: 47.7s	remaining: 2m 54s
# 1600:	learn: 0.0107258	total: 52.5s	remaining: 2m 57s
# 1700:	learn: 0.0100366	total: 57.4s	remaining: 2m 58s
# 1800:	learn: 0.0094234	total: 1m 2s	remaining: 2m 59s
# 1900:	learn: 0.0088471	total: 1m 7s	remaining: 2m 59s
# 2000:	learn: 0.0083364	total: 1m 11s	remaining: 2m 59s
# 2100:	learn: 0.0078558	total: 1m 16s	remaining: 2m 59s
# 2200:	learn: 0.0074168	total: 1m 21s	remaining: 2m 57s
# 2300:	learn: 0.0070157	total: 1m 26s	remaining: 2m 56s
# 2400:	learn: 0.0067075	total: 1m 31s	remaining: 2m 54s
# 2500:	learn: 0.0063507	total: 1m 36s	remaining: 2m 52s
# 2600:	learn: 0.0060179	total: 1m 40s	remaining: 2m 50s
# 2700:	learn: 0.0057465	total: 1m 45s	remaining: 2m 48s
# 2800:	learn: 0.0054315	total: 1m 50s	remaining: 2m 45s
# 2900:	learn: 0.0052335	total: 1m 55s	remaining: 2m 43s
# 3000:	learn: 0.0049911	total: 2m	remaining: 2m 40s
# 3100:	learn: 0.0048266	total: 2m 5s	remaining: 2m 37s
# 3200:	learn: 0.0046026	total: 2m 10s	remaining: 2m 34s
# 3300:	learn: 0.0044276	total: 2m 14s	remaining: 2m 31s
# 3400:	learn: 0.0042506	total: 2m 19s	remaining: 2m 27s
# 3500:	learn: 0.0041038	total: 2m 24s	remaining: 2m 24s
# 3600:	learn: 0.0039190	total: 2m 29s	remaining: 2m 21s
# 3700:	learn: 0.0038039	total: 2m 34s	remaining: 2m 17s
# 3800:	learn: 0.0036756	total: 2m 39s	remaining: 2m 14s
# 3900:	learn: 0.0035435	total: 2m 44s	remaining: 2m 10s
# 4000:	learn: 0.0034041	total: 2m 49s	remaining: 2m 6s
# 4100:	learn: 0.0032660	total: 2m 53s	remaining: 2m 2s
# 4200:	learn: 0.0032175	total: 2m 58s	remaining: 1m 59s
# 4300:	learn: 0.0031668	total: 3m 3s	remaining: 1m 55s
# 4400:	learn: 0.0030371	total: 3m 8s	remaining: 1m 51s
# 4500:	learn: 0.0029834	total: 3m 13s	remaining: 1m 47s
# 4600:	learn: 0.0028643	total: 3m 18s	remaining: 1m 43s
# 4700:	learn: 0.0027941	total: 3m 23s	remaining: 1m 39s
# 4800:	learn: 0.0027632	total: 3m 28s	remaining: 1m 35s
# 4900:	learn: 0.0027329	total: 3m 33s	remaining: 1m 31s
# 5000:	learn: 0.0025725	total: 3m 38s	remaining: 1m 27s
# 5100:	learn: 0.0025104	total: 3m 42s	remaining: 1m 22s
# 5200:	learn: 0.0024931	total: 3m 47s	remaining: 1m 18s
# 5300:	learn: 0.0025022	total: 3m 52s	remaining: 1m 14s
# 5400:	learn: 0.0024257	total: 3m 57s	remaining: 1m 10s
# 5500:	learn: 0.0024055	total: 4m 2s	remaining: 1m 6s
# 5600:	learn: 0.0023159	total: 4m 7s	remaining: 1m 1s
# 5700:	learn: 0.0022779	total: 4m 12s	remaining: 57.5s
# 5800:	learn: 0.0023062	total: 4m 17s	remaining: 53.1s
# 5900:	learn: 0.0022275	total: 4m 21s	remaining: 48.8s
# 6000:	learn: 0.0022098	total: 4m 26s	remaining: 44.4s
# 6100:	learn: 0.0021968	total: 4m 31s	remaining: 40s
# 6200:	learn: 0.0020982	total: 4m 36s	remaining: 35.6s
# 6300:	learn: 0.0021595	total: 4m 41s	remaining: 31.2s
# 6400:	learn: 0.0020474	total: 4m 46s	remaining: 26.8s
# 6500:	learn: 0.0020597	total: 4m 51s	remaining: 22.3s
# 6600:	learn: 0.0020488	total: 4m 55s	remaining: 17.9s
# 6700:	learn: 0.0020584	total: 5m	remaining: 13.4s
# 6800:	learn: 0.0019871	total: 5m 5s	remaining: 8.94s
# 6900:	learn: 0.0020123	total: 5m 10s	remaining: 4.46s
# 6999:	learn: 0.0019217	total: 5m 15s	remaining: 0us
# 10 ----------------------------------------------------------------------------------------------------
# (912, 96)
# 0:	learn: 0.1184075	total: 14.3ms	remaining: 1m 39s
# 100:	learn: 0.0299169	total: 2.54s	remaining: 2m 53s
# 200:	learn: 0.0275358	total: 4.99s	remaining: 2m 48s
# 300:	learn: 0.0261934	total: 7.09s	remaining: 2m 37s
# 400:	learn: 0.0249003	total: 9.68s	remaining: 2m 39s
# 500:	learn: 0.0237602	total: 11.8s	remaining: 2m 33s
# 600:	learn: 0.0226728	total: 14.6s	remaining: 2m 35s
# 700:	learn: 0.0214617	total: 17.8s	remaining: 2m 39s
# 800:	learn: 0.0205288	total: 20.6s	remaining: 2m 39s
# 900:	learn: 0.0195744	total: 24s	remaining: 2m 42s
# 1000:	learn: 0.0186779	total: 27.8s	remaining: 2m 46s
# 1100:	learn: 0.0175881	total: 32.8s	remaining: 2m 55s
# 1200:	learn: 0.0165943	total: 38.2s	remaining: 3m 4s
# 1300:	learn: 0.0156597	total: 43.8s	remaining: 3m 11s
# 1400:	learn: 0.0148514	total: 49.5s	remaining: 3m 17s
# 1500:	learn: 0.0140997	total: 55.1s	remaining: 3m 21s
# 1600:	learn: 0.0133070	total: 1m	remaining: 3m 24s
# 1700:	learn: 0.0126094	total: 1m 6s	remaining: 3m 26s
# 1800:	learn: 0.0119640	total: 1m 11s	remaining: 3m 27s
# 1900:	learn: 0.0113846	total: 1m 17s	remaining: 3m 28s
# 2000:	learn: 0.0107991	total: 1m 23s	remaining: 3m 27s
# 2100:	learn: 0.0101940	total: 1m 28s	remaining: 3m 27s
# 2200:	learn: 0.0096782	total: 1m 34s	remaining: 3m 26s
# 2300:	learn: 0.0091529	total: 1m 40s	remaining: 3m 24s
# 2400:	learn: 0.0087404	total: 1m 45s	remaining: 3m 22s
# 2500:	learn: 0.0083280	total: 1m 51s	remaining: 3m 20s
# 2600:	learn: 0.0079622	total: 1m 57s	remaining: 3m 18s
# 2700:	learn: 0.0075900	total: 2m 2s	remaining: 3m 15s
# 2800:	learn: 0.0072093	total: 2m 8s	remaining: 3m 12s
# 2900:	learn: 0.0068562	total: 2m 14s	remaining: 3m 9s
# 3000:	learn: 0.0065340	total: 2m 19s	remaining: 3m 6s
# 3100:	learn: 0.0062737	total: 2m 25s	remaining: 3m 2s
# 3200:	learn: 0.0060038	total: 2m 30s	remaining: 2m 59s
# 3300:	learn: 0.0057489	total: 2m 36s	remaining: 2m 55s
# 3400:	learn: 0.0054990	total: 2m 42s	remaining: 2m 51s
# 3500:	learn: 0.0052546	total: 2m 47s	remaining: 2m 47s
# 3600:	learn: 0.0050735	total: 2m 53s	remaining: 2m 43s
# 3700:	learn: 0.0049170	total: 2m 59s	remaining: 2m 39s
# 3800:	learn: 0.0047075	total: 3m 4s	remaining: 2m 35s
# 3900:	learn: 0.0045225	total: 3m 10s	remaining: 2m 31s
# 4000:	learn: 0.0043579	total: 3m 16s	remaining: 2m 26s
# 4100:	learn: 0.0042309	total: 3m 21s	remaining: 2m 22s
# 4200:	learn: 0.0040868	total: 3m 27s	remaining: 2m 18s
# 4300:	learn: 0.0040016	total: 3m 32s	remaining: 2m 13s
# 4400:	learn: 0.0039140	total: 3m 38s	remaining: 2m 9s
# 4500:	learn: 0.0037332	total: 3m 44s	remaining: 2m 4s
# 4600:	learn: 0.0037001	total: 3m 49s	remaining: 1m 59s
# 4700:	learn: 0.0035278	total: 3m 55s	remaining: 1m 55s
# 4800:	learn: 0.0034263	total: 4m 1s	remaining: 1m 50s
# 4900:	learn: 0.0033297	total: 4m 6s	remaining: 1m 45s
# 5000:	learn: 0.0032588	total: 4m 12s	remaining: 1m 40s
# 5100:	learn: 0.0031628	total: 4m 18s	remaining: 1m 36s
# 5200:	learn: 0.0031261	total: 4m 23s	remaining: 1m 31s
# 5300:	learn: 0.0029845	total: 4m 29s	remaining: 1m 26s
# 5400:	learn: 0.0029752	total: 4m 34s	remaining: 1m 21s
# 5500:	learn: 0.0029492	total: 4m 40s	remaining: 1m 16s
# 5600:	learn: 0.0028197	total: 4m 46s	remaining: 1m 11s
# 5700:	learn: 0.0028091	total: 4m 51s	remaining: 1m 6s
# 5800:	learn: 0.0027105	total: 4m 57s	remaining: 1m 1s
# 5900:	learn: 0.0025798	total: 5m 3s	remaining: 56.5s
# 6000:	learn: 0.0025881	total: 5m 9s	remaining: 51.4s
# 6100:	learn: 0.0025562	total: 5m 14s	remaining: 46.4s
# 6200:	learn: 0.0024770	total: 5m 20s	remaining: 41.3s
# 6300:	learn: 0.0024762	total: 5m 25s	remaining: 36.2s
# 6400:	learn: 0.0024303	total: 5m 31s	remaining: 31s
# 6500:	learn: 0.0024085	total: 5m 37s	remaining: 25.9s
# 6600:	learn: 0.0023306	total: 5m 42s	remaining: 20.7s
# 6700:	learn: 0.0023254	total: 5m 48s	remaining: 15.6s
# 6800:	learn: 0.0023055	total: 5m 54s	remaining: 10.4s
# 6900:	learn: 0.0022574	total: 5m 59s	remaining: 5.16s
# 6999:	learn: 0.0022367	total: 6m 5s	remaining: 0us
# 11 ----------------------------------------------------------------------------------------------------
# (288, 96)
# 0:	learn: 0.0851409	total: 9.43ms	remaining: 1m 6s
# 100:	learn: 0.0217762	total: 1.95s	remaining: 2m 12s
# 200:	learn: 0.0182756	total: 4.58s	remaining: 2m 35s
# 300:	learn: 0.0165751	total: 6.82s	remaining: 2m 31s
# 400:	learn: 0.0151061	total: 9.14s	remaining: 2m 30s
# 500:	learn: 0.0137016	total: 11.5s	remaining: 2m 29s
# 600:	learn: 0.0124598	total: 14s	remaining: 2m 28s
# 700:	learn: 0.0111310	total: 16.6s	remaining: 2m 28s
# 800:	learn: 0.0100382	total: 19.4s	remaining: 2m 29s
# 900:	learn: 0.0090674	total: 22.6s	remaining: 2m 32s
# 1000:	learn: 0.0080657	total: 26.8s	remaining: 2m 40s
# 1100:	learn: 0.0072038	total: 31.3s	remaining: 2m 47s
# 1200:	learn: 0.0064334	total: 36.3s	remaining: 2m 55s
# 1300:	learn: 0.0058338	total: 41.1s	remaining: 3m
# 1400:	learn: 0.0053069	total: 46s	remaining: 3m 3s
# 1500:	learn: 0.0049031	total: 50.9s	remaining: 3m 6s
# 1600:	learn: 0.0045490	total: 55.8s	remaining: 3m 8s
# 1700:	learn: 0.0042442	total: 1m	remaining: 3m 9s
# 1800:	learn: 0.0038898	total: 1m 5s	remaining: 3m 9s
# 1900:	learn: 0.0036975	total: 1m 10s	remaining: 3m 8s
# 2000:	learn: 0.0034179	total: 1m 15s	remaining: 3m 8s
# 2100:	learn: 0.0032800	total: 1m 20s	remaining: 3m 6s
# 2200:	learn: 0.0031816	total: 1m 25s	remaining: 3m 5s
# 2300:	learn: 0.0030077	total: 1m 29s	remaining: 3m 3s
# 2400:	learn: 0.0028395	total: 1m 34s	remaining: 3m 1s
# 2500:	learn: 0.0027253	total: 1m 39s	remaining: 2m 59s
# 2600:	learn: 0.0025758	total: 1m 44s	remaining: 2m 56s
# 2700:	learn: 0.0025034	total: 1m 49s	remaining: 2m 53s
# 2800:	learn: 0.0024525	total: 1m 54s	remaining: 2m 51s
# 2900:	learn: 0.0023467	total: 1m 59s	remaining: 2m 48s
# 3000:	learn: 0.0023239	total: 2m 4s	remaining: 2m 45s
# 3100:	learn: 0.0022493	total: 2m 8s	remaining: 2m 42s
# 3200:	learn: 0.0021152	total: 2m 13s	remaining: 2m 38s
# 3300:	learn: 0.0020669	total: 2m 18s	remaining: 2m 35s
# 3400:	learn: 0.0020614	total: 2m 23s	remaining: 2m 31s
# 3500:	learn: 0.0020895	total: 2m 28s	remaining: 2m 28s
# 3600:	learn: 0.0019847	total: 2m 33s	remaining: 2m 24s
# 3700:	learn: 0.0019959	total: 2m 38s	remaining: 2m 20s
# 3800:	learn: 0.0019206	total: 2m 43s	remaining: 2m 17s
# 3900:	learn: 0.0019120	total: 2m 47s	remaining: 2m 13s
# 4000:	learn: 0.0019251	total: 2m 52s	remaining: 2m 9s
# 4100:	learn: 0.0018592	total: 2m 57s	remaining: 2m 5s
# 4200:	learn: 0.0018463	total: 3m 2s	remaining: 2m 1s
# 4300:	learn: 0.0017998	total: 3m 7s	remaining: 1m 57s
# 4400:	learn: 0.0017842	total: 3m 12s	remaining: 1m 53s
# 4500:	learn: 0.0018144	total: 3m 17s	remaining: 1m 49s
# 4600:	learn: 0.0017190	total: 3m 22s	remaining: 1m 45s
# 4700:	learn: 0.0017401	total: 3m 27s	remaining: 1m 41s
# 4800:	learn: 0.0016771	total: 3m 32s	remaining: 1m 37s
# 4900:	learn: 0.0016594	total: 3m 37s	remaining: 1m 33s
# 5000:	learn: 0.0017052	total: 3m 42s	remaining: 1m 28s
# 5100:	learn: 0.0016807	total: 3m 47s	remaining: 1m 24s
# 5200:	learn: 0.0016562	total: 3m 51s	remaining: 1m 20s
# 5300:	learn: 0.0017034	total: 3m 56s	remaining: 1m 15s
# 5400:	learn: 0.0016711	total: 4m 1s	remaining: 1m 11s
# 5500:	learn: 0.0017005	total: 4m 6s	remaining: 1m 7s
# 5600:	learn: 0.0015988	total: 4m 11s	remaining: 1m 2s
# 5700:	learn: 0.0016556	total: 4m 16s	remaining: 58.4s
# 5800:	learn: 0.0016174	total: 4m 21s	remaining: 54s
# 5900:	learn: 0.0016152	total: 4m 26s	remaining: 49.6s
# 6000:	learn: 0.0016231	total: 4m 30s	remaining: 45.1s
# 6100:	learn: 0.0015386	total: 4m 35s	remaining: 40.6s
# 6200:	learn: 0.0016069	total: 4m 40s	remaining: 36.2s
# 6300:	learn: 0.0016046	total: 4m 45s	remaining: 31.7s
# 6400:	learn: 0.0015804	total: 4m 50s	remaining: 27.2s
# 6500:	learn: 0.0015921	total: 4m 55s	remaining: 22.7s
# 6600:	learn: 0.0015612	total: 4m 59s	remaining: 18.1s
# 6700:	learn: 0.0016016	total: 5m 4s	remaining: 13.6s
# 6800:	learn: 0.0015530	total: 5m 9s	remaining: 9.06s
# 6900:	learn: 0.0015421	total: 5m 14s	remaining: 4.51s
# 6999:	learn: 0.0015156	total: 5m 19s	remaining: 0us
# 12 ----------------------------------------------------------------------------------------------------
# (576, 96)
# 0:	learn: 0.1164939	total: 54.5ms	remaining: 6m 21s
# 100:	learn: 0.0302096	total: 2.16s	remaining: 2m 27s
# 200:	learn: 0.0271072	total: 4.93s	remaining: 2m 46s
# 300:	learn: 0.0252487	total: 7.92s	remaining: 2m 56s
# 400:	learn: 0.0233485	total: 10.7s	remaining: 2m 55s
# 500:	learn: 0.0222565	total: 13.3s	remaining: 2m 52s
# 600:	learn: 0.0212667	total: 15.8s	remaining: 2m 48s
# 700:	learn: 0.0201033	total: 18.6s	remaining: 2m 47s
# 800:	learn: 0.0191743	total: 21.2s	remaining: 2m 44s
# 900:	learn: 0.0180881	total: 24.6s	remaining: 2m 46s
# 1000:	learn: 0.0169829	total: 28.7s	remaining: 2m 52s
# 1100:	learn: 0.0158646	total: 33.7s	remaining: 3m
# 1200:	learn: 0.0148246	total: 39.2s	remaining: 3m 9s
# 1300:	learn: 0.0139413	total: 44.9s	remaining: 3m 16s
# 1400:	learn: 0.0131391	total: 50.5s	remaining: 3m 21s
# 1500:	learn: 0.0123029	total: 56.1s	remaining: 3m 25s
# 1600:	learn: 0.0115740	total: 1m 1s	remaining: 3m 28s
# 1700:	learn: 0.0109146	total: 1m 7s	remaining: 3m 30s
# 1800:	learn: 0.0103146	total: 1m 13s	remaining: 3m 31s
# 1900:	learn: 0.0097549	total: 1m 19s	remaining: 3m 32s
# 2000:	learn: 0.0092493	total: 1m 24s	remaining: 3m 31s
# 2100:	learn: 0.0087380	total: 1m 30s	remaining: 3m 30s
# 2200:	learn: 0.0083236	total: 1m 36s	remaining: 3m 29s
# 2300:	learn: 0.0079247	total: 1m 41s	remaining: 3m 27s
# 2400:	learn: 0.0075280	total: 1m 47s	remaining: 3m 25s
# 2500:	learn: 0.0071779	total: 1m 53s	remaining: 3m 23s
# 2600:	learn: 0.0068186	total: 1m 58s	remaining: 3m 20s
# 2700:	learn: 0.0065346	total: 2m 4s	remaining: 3m 17s
# 2800:	learn: 0.0062449	total: 2m 9s	remaining: 3m 14s
# 2900:	learn: 0.0059552	total: 2m 15s	remaining: 3m 11s
# 3000:	learn: 0.0057094	total: 2m 21s	remaining: 3m 8s
# 3100:	learn: 0.0054335	total: 2m 26s	remaining: 3m 4s
# 3200:	learn: 0.0052273	total: 2m 32s	remaining: 3m 1s
# 3300:	learn: 0.0050604	total: 2m 38s	remaining: 2m 57s
# 3400:	learn: 0.0048739	total: 2m 43s	remaining: 2m 53s
# 3500:	learn: 0.0047337	total: 2m 49s	remaining: 2m 49s
# 3600:	learn: 0.0046170	total: 2m 55s	remaining: 2m 45s
# 3700:	learn: 0.0044695	total: 3m	remaining: 2m 41s
# 3800:	learn: 0.0042606	total: 3m 6s	remaining: 2m 36s
# 3900:	learn: 0.0041346	total: 3m 12s	remaining: 2m 32s
# 4000:	learn: 0.0040482	total: 3m 17s	remaining: 2m 28s
# 4100:	learn: 0.0039077	total: 3m 23s	remaining: 2m 23s
# 4200:	learn: 0.0037506	total: 3m 29s	remaining: 2m 19s
# 4300:	learn: 0.0036526	total: 3m 34s	remaining: 2m 14s
# 4400:	learn: 0.0035781	total: 3m 40s	remaining: 2m 10s
# 4500:	learn: 0.0034663	total: 3m 46s	remaining: 2m 5s
# 4600:	learn: 0.0033799	total: 3m 51s	remaining: 2m
# 4700:	learn: 0.0033502	total: 3m 57s	remaining: 1m 56s
# 4800:	learn: 0.0032324	total: 4m 3s	remaining: 1m 51s
# 4900:	learn: 0.0031379	total: 4m 8s	remaining: 1m 46s
# 5000:	learn: 0.0031638	total: 4m 14s	remaining: 1m 41s
# 5100:	learn: 0.0030310	total: 4m 19s	remaining: 1m 36s
# 5200:	learn: 0.0029987	total: 4m 25s	remaining: 1m 31s
# 5300:	learn: 0.0029472	total: 4m 31s	remaining: 1m 26s
# 5400:	learn: 0.0028608	total: 4m 36s	remaining: 1m 21s
# 5500:	learn: 0.0028115	total: 4m 42s	remaining: 1m 16s
# 5600:	learn: 0.0028002	total: 4m 47s	remaining: 1m 11s
# 5700:	learn: 0.0027244	total: 4m 53s	remaining: 1m 6s
# 5800:	learn: 0.0027236	total: 4m 59s	remaining: 1m 1s
# 5900:	learn: 0.0026516	total: 5m 4s	remaining: 56.8s
# 6000:	learn: 0.0026235	total: 5m 10s	remaining: 51.7s
# 6100:	learn: 0.0025676	total: 5m 16s	remaining: 46.6s
# 6200:	learn: 0.0025546	total: 5m 21s	remaining: 41.5s
# 6300:	learn: 0.0025508	total: 5m 27s	remaining: 36.3s
# 6400:	learn: 0.0024924	total: 5m 33s	remaining: 31.2s
# 6500:	learn: 0.0024666	total: 5m 38s	remaining: 26s
# 6600:	learn: 0.0024413	total: 5m 44s	remaining: 20.8s
# 6700:	learn: 0.0023793	total: 5m 50s	remaining: 15.6s
# 6800:	learn: 0.0023331	total: 5m 55s	remaining: 10.4s
# 6900:	learn: 0.0023053	total: 6m 1s	remaining: 5.18s
# 6999:	learn: 0.0023583	total: 6m 6s	remaining: 0us
# 13 ----------------------------------------------------------------------------------------------------
# (336, 96)
# 0:	learn: 0.1171018	total: 9.36ms	remaining: 1m 5s
# 100:	learn: 0.0276632	total: 1.95s	remaining: 2m 13s
# 200:	learn: 0.0252147	total: 3.95s	remaining: 2m 13s
# 300:	learn: 0.0238130	total: 5.9s	remaining: 2m 11s
# 400:	learn: 0.0222962	total: 8.16s	remaining: 2m 14s
# 500:	learn: 0.0210477	total: 10.2s	remaining: 2m 12s
# 600:	learn: 0.0195930	total: 12.6s	remaining: 2m 14s
# 700:	learn: 0.0182222	total: 15.1s	remaining: 2m 16s
# 800:	learn: 0.0171273	total: 17.7s	remaining: 2m 16s
# 900:	learn: 0.0158368	total: 21s	remaining: 2m 22s
# 1000:	learn: 0.0146721	total: 24.8s	remaining: 2m 28s
# 1100:	learn: 0.0134620	total: 29.6s	remaining: 2m 38s
# 1200:	learn: 0.0123773	total: 34.5s	remaining: 2m 46s
# 1300:	learn: 0.0114622	total: 39.4s	remaining: 2m 52s
# 1400:	learn: 0.0105190	total: 44.2s	remaining: 2m 56s
# 1500:	learn: 0.0096617	total: 49.1s	remaining: 2m 59s
# 1600:	learn: 0.0088497	total: 53.9s	remaining: 3m 1s
# 1700:	learn: 0.0082213	total: 58.8s	remaining: 3m 3s
# 1800:	learn: 0.0076132	total: 1m 3s	remaining: 3m 3s
# 1900:	learn: 0.0071008	total: 1m 8s	remaining: 3m 3s
# 2000:	learn: 0.0066284	total: 1m 13s	remaining: 3m 3s
# 2100:	learn: 0.0061967	total: 1m 18s	remaining: 3m 2s
# 2200:	learn: 0.0058295	total: 1m 23s	remaining: 3m 1s
# 2300:	learn: 0.0054258	total: 1m 27s	remaining: 2m 59s
# 2400:	learn: 0.0050807	total: 1m 32s	remaining: 2m 57s
# 2500:	learn: 0.0048159	total: 1m 37s	remaining: 2m 55s
# 2600:	learn: 0.0045100	total: 1m 42s	remaining: 2m 53s
# 2700:	learn: 0.0042860	total: 1m 47s	remaining: 2m 51s
# 2800:	learn: 0.0040462	total: 1m 52s	remaining: 2m 48s
# 2900:	learn: 0.0038265	total: 1m 57s	remaining: 2m 45s
# 3000:	learn: 0.0036296	total: 2m 2s	remaining: 2m 42s
# 3100:	learn: 0.0035108	total: 2m 6s	remaining: 2m 39s
# 3200:	learn: 0.0033668	total: 2m 11s	remaining: 2m 36s
# 3300:	learn: 0.0032597	total: 2m 16s	remaining: 2m 33s
# 3400:	learn: 0.0030390	total: 2m 21s	remaining: 2m 29s
# 3500:	learn: 0.0029598	total: 2m 26s	remaining: 2m 26s
# 3600:	learn: 0.0029264	total: 2m 31s	remaining: 2m 22s
# 3700:	learn: 0.0027660	total: 2m 36s	remaining: 2m 19s
# 3800:	learn: 0.0026608	total: 2m 40s	remaining: 2m 15s
# 3900:	learn: 0.0025755	total: 2m 45s	remaining: 2m 11s
# 4000:	learn: 0.0025222	total: 2m 50s	remaining: 2m 7s
# 4100:	learn: 0.0024625	total: 2m 55s	remaining: 2m 4s
# 4200:	learn: 0.0024527	total: 3m	remaining: 2m
# 4300:	learn: 0.0023118	total: 3m 5s	remaining: 1m 56s
# 4400:	learn: 0.0023331	total: 3m 10s	remaining: 1m 52s
# 4500:	learn: 0.0022297	total: 3m 15s	remaining: 1m 48s
# 4600:	learn: 0.0021242	total: 3m 19s	remaining: 1m 44s
# 4700:	learn: 0.0021549	total: 3m 24s	remaining: 1m 40s
# 4800:	learn: 0.0019972	total: 3m 29s	remaining: 1m 36s
# 4900:	learn: 0.0020251	total: 3m 34s	remaining: 1m 31s
# 5000:	learn: 0.0020331	total: 3m 39s	remaining: 1m 27s
# 5100:	learn: 0.0019608	total: 3m 44s	remaining: 1m 23s
# 5200:	learn: 0.0019213	total: 3m 49s	remaining: 1m 19s
# 5300:	learn: 0.0019423	total: 3m 55s	remaining: 1m 15s
# 5400:	learn: 0.0019705	total: 4m	remaining: 1m 11s
# 5500:	learn: 0.0019025	total: 4m 5s	remaining: 1m 6s
# 5600:	learn: 0.0018468	total: 4m 10s	remaining: 1m 2s
# 5700:	learn: 0.0018479	total: 4m 15s	remaining: 58.2s
# 5800:	learn: 0.0018478	total: 4m 20s	remaining: 53.8s
# 5900:	learn: 0.0018333	total: 4m 25s	remaining: 49.4s
# 6000:	learn: 0.0018505	total: 4m 30s	remaining: 45s
# 6100:	learn: 0.0018239	total: 4m 35s	remaining: 40.5s
# 6200:	learn: 0.0018229	total: 4m 39s	remaining: 36.1s
# 6300:	learn: 0.0018206	total: 4m 44s	remaining: 31.6s
# 6400:	learn: 0.0017534	total: 4m 49s	remaining: 27.1s
# 6500:	learn: 0.0017675	total: 4m 54s	remaining: 22.6s
# 6600:	learn: 0.0017661	total: 5m	remaining: 18.1s
# 6700:	learn: 0.0017125	total: 5m 5s	remaining: 13.7s
# 6800:	learn: 0.0016739	total: 5m 10s	remaining: 9.1s
# 6900:	learn: 0.0017040	total: 5m 16s	remaining: 4.54s
# 6999:	learn: 0.0016623	total: 5m 21s	remaining: 0us
# 14 ----------------------------------------------------------------------------------------------------
# (336, 96)
# 0:	learn: 0.1297750	total: 10.1ms	remaining: 1m 10s
# 100:	learn: 0.0256558	total: 2.13s	remaining: 2m 25s
# 200:	learn: 0.0225468	total: 4.54s	remaining: 2m 33s
# 300:	learn: 0.0206293	total: 6.56s	remaining: 2m 26s
# 400:	learn: 0.0191439	total: 8.69s	remaining: 2m 23s
# 500:	learn: 0.0175220	total: 11.3s	remaining: 2m 26s
# 600:	learn: 0.0161650	total: 13.8s	remaining: 2m 26s
# 700:	learn: 0.0148046	total: 16.2s	remaining: 2m 25s
# 800:	learn: 0.0136324	total: 18.8s	remaining: 2m 25s
# 900:	learn: 0.0125800	total: 21.8s	remaining: 2m 27s
# 1000:	learn: 0.0114635	total: 25.9s	remaining: 2m 35s
# 1100:	learn: 0.0103904	total: 30.4s	remaining: 2m 42s
# 1200:	learn: 0.0093730	total: 35.2s	remaining: 2m 49s
# 1300:	learn: 0.0085368	total: 40.1s	remaining: 2m 55s
# 1400:	learn: 0.0077919	total: 45s	remaining: 2m 59s
# 1500:	learn: 0.0071769	total: 49.9s	remaining: 3m 2s
# 1600:	learn: 0.0065683	total: 54.7s	remaining: 3m 4s
# 1700:	learn: 0.0060418	total: 59.6s	remaining: 3m 5s
# 1800:	learn: 0.0056032	total: 1m 4s	remaining: 3m 6s
# 1900:	learn: 0.0052580	total: 1m 9s	remaining: 3m 6s
# 2000:	learn: 0.0048893	total: 1m 14s	remaining: 3m 5s
# 2100:	learn: 0.0045597	total: 1m 19s	remaining: 3m 4s
# 2200:	learn: 0.0042959	total: 1m 24s	remaining: 3m 3s
# 2300:	learn: 0.0039946	total: 1m 29s	remaining: 3m 1s
# 2400:	learn: 0.0038382	total: 1m 33s	remaining: 2m 59s
# 2500:	learn: 0.0036207	total: 1m 38s	remaining: 2m 57s
# 2600:	learn: 0.0034435	total: 1m 43s	remaining: 2m 55s
# 2700:	learn: 0.0032712	total: 1m 48s	remaining: 2m 53s
# 2800:	learn: 0.0031242	total: 1m 53s	remaining: 2m 50s
# 2900:	learn: 0.0030453	total: 1m 58s	remaining: 2m 47s
# 3000:	learn: 0.0029263	total: 2m 3s	remaining: 2m 44s
# 3100:	learn: 0.0027643	total: 2m 8s	remaining: 2m 41s
# 3200:	learn: 0.0026912	total: 2m 13s	remaining: 2m 38s
# 3300:	learn: 0.0026195	total: 2m 18s	remaining: 2m 34s
# 3400:	learn: 0.0024642	total: 2m 23s	remaining: 2m 31s
# 3500:	learn: 0.0024172	total: 2m 27s	remaining: 2m 27s
# 3600:	learn: 0.0023561	total: 2m 32s	remaining: 2m 24s
# 3700:	learn: 0.0022917	total: 2m 37s	remaining: 2m 20s
# 3800:	learn: 0.0022452	total: 2m 42s	remaining: 2m 16s
# 3900:	learn: 0.0021947	total: 2m 47s	remaining: 2m 13s
# 4000:	learn: 0.0020681	total: 2m 52s	remaining: 2m 9s
# 4100:	learn: 0.0020510	total: 2m 57s	remaining: 2m 5s
# 4200:	learn: 0.0019759	total: 3m 2s	remaining: 2m 1s
# 4300:	learn: 0.0019720	total: 3m 6s	remaining: 1m 57s
# 4400:	learn: 0.0019348	total: 3m 11s	remaining: 1m 53s
# 4500:	learn: 0.0019267	total: 3m 16s	remaining: 1m 49s
# 4600:	learn: 0.0018465	total: 3m 21s	remaining: 1m 45s
# 4700:	learn: 0.0018313	total: 3m 26s	remaining: 1m 40s
# 4800:	learn: 0.0017993	total: 3m 31s	remaining: 1m 36s
# 4900:	learn: 0.0017775	total: 3m 36s	remaining: 1m 32s
# 5000:	learn: 0.0017638	total: 3m 41s	remaining: 1m 28s
# 5100:	learn: 0.0017230	total: 3m 45s	remaining: 1m 24s
# 5200:	learn: 0.0017675	total: 3m 50s	remaining: 1m 19s
# 5300:	learn: 0.0017833	total: 3m 55s	remaining: 1m 15s
# 5400:	learn: 0.0017462	total: 4m	remaining: 1m 11s
# 5500:	learn: 0.0016438	total: 4m 5s	remaining: 1m 6s
# 5600:	learn: 0.0016802	total: 4m 10s	remaining: 1m 2s
# 5700:	learn: 0.0016562	total: 4m 15s	remaining: 58.2s
# 5800:	learn: 0.0016654	total: 4m 20s	remaining: 53.8s
# 5900:	learn: 0.0016426	total: 4m 25s	remaining: 49.4s
# 6000:	learn: 0.0015915	total: 4m 30s	remaining: 45s
# 6100:	learn: 0.0016316	total: 4m 34s	remaining: 40.5s
# 6200:	learn: 0.0015886	total: 4m 39s	remaining: 36.1s
# 6300:	learn: 0.0016319	total: 4m 44s	remaining: 31.6s
# 6400:	learn: 0.0015508	total: 4m 49s	remaining: 27.1s
# 6500:	learn: 0.0015844	total: 4m 54s	remaining: 22.6s
# 6600:	learn: 0.0015888	total: 4m 59s	remaining: 18.1s
# 6700:	learn: 0.0015515	total: 5m 4s	remaining: 13.6s
# 6800:	learn: 0.0016332	total: 5m 9s	remaining: 9.04s
# 6900:	learn: 0.0016027	total: 5m 13s	remaining: 4.5s
# 6999:	learn: 0.0015896	total: 5m 18s	remaining: 0us
# 15 ----------------------------------------------------------------------------------------------------
# (432, 96)
# 0:	learn: 0.1138953	total: 13.2ms	remaining: 1m 32s
# 100:	learn: 0.0276275	total: 1.62s	remaining: 1m 50s
# 200:	learn: 0.0251931	total: 3.69s	remaining: 2m 4s
# 300:	learn: 0.0235397	total: 5.67s	remaining: 2m 6s
# 400:	learn: 0.0220668	total: 7.75s	remaining: 2m 7s
# 500:	learn: 0.0206341	total: 9.94s	remaining: 2m 8s
# 600:	learn: 0.0194040	total: 12.5s	remaining: 2m 13s
# 700:	learn: 0.0182107	total: 15.1s	remaining: 2m 15s
# 800:	learn: 0.0170509	total: 17.8s	remaining: 2m 17s
# 900:	learn: 0.0156864	total: 20.8s	remaining: 2m 20s
# 1000:	learn: 0.0146580	total: 24.3s	remaining: 2m 25s
# 1100:	learn: 0.0135943	total: 28.7s	remaining: 2m 34s
# 1200:	learn: 0.0124840	total: 33.5s	remaining: 2m 41s
# 1300:	learn: 0.0115470	total: 38.4s	remaining: 2m 48s
# 1400:	learn: 0.0106638	total: 43.2s	remaining: 2m 52s
# 1500:	learn: 0.0098217	total: 48.1s	remaining: 2m 56s
# 1600:	learn: 0.0091019	total: 53s	remaining: 2m 58s
# 1700:	learn: 0.0084923	total: 57.9s	remaining: 3m
# 1800:	learn: 0.0079487	total: 1m 2s	remaining: 3m 1s
# 1900:	learn: 0.0073552	total: 1m 7s	remaining: 3m 1s
# 2000:	learn: 0.0068457	total: 1m 12s	remaining: 3m 1s
# 2100:	learn: 0.0063681	total: 1m 17s	remaining: 3m
# 2200:	learn: 0.0060217	total: 1m 22s	remaining: 2m 59s
# 2300:	learn: 0.0056292	total: 1m 27s	remaining: 2m 58s
# 2400:	learn: 0.0053361	total: 1m 32s	remaining: 2m 56s
# 2500:	learn: 0.0050423	total: 1m 36s	remaining: 2m 54s
# 2600:	learn: 0.0047407	total: 1m 41s	remaining: 2m 52s
# 2700:	learn: 0.0045196	total: 1m 46s	remaining: 2m 49s
# 2800:	learn: 0.0043005	total: 1m 51s	remaining: 2m 47s
# 2900:	learn: 0.0040700	total: 1m 56s	remaining: 2m 44s
# 3000:	learn: 0.0039493	total: 2m 1s	remaining: 2m 41s
# 3100:	learn: 0.0037181	total: 2m 5s	remaining: 2m 38s
# 3200:	learn: 0.0035970	total: 2m 10s	remaining: 2m 35s
# 3300:	learn: 0.0034633	total: 2m 15s	remaining: 2m 32s
# 3400:	learn: 0.0033067	total: 2m 20s	remaining: 2m 28s
# 3500:	learn: 0.0031676	total: 2m 25s	remaining: 2m 25s
# 3600:	learn: 0.0031062	total: 2m 30s	remaining: 2m 21s
# 3700:	learn: 0.0029619	total: 2m 35s	remaining: 2m 18s
# 3800:	learn: 0.0028695	total: 2m 40s	remaining: 2m 14s
# 3900:	learn: 0.0027857	total: 2m 45s	remaining: 2m 11s
# 4000:	learn: 0.0026552	total: 2m 49s	remaining: 2m 7s
# 4100:	learn: 0.0025856	total: 2m 54s	remaining: 2m 3s
# 4200:	learn: 0.0025208	total: 3m	remaining: 2m
# 4300:	learn: 0.0024858	total: 3m 8s	remaining: 1m 58s
# 4400:	learn: 0.0024024	total: 3m 13s	remaining: 1m 54s
# 4500:	learn: 0.0023519	total: 3m 18s	remaining: 1m 49s
# 4600:	learn: 0.0023228	total: 3m 22s	remaining: 1m 45s
# 4700:	learn: 0.0022410	total: 3m 27s	remaining: 1m 41s
# 4800:	learn: 0.0021837	total: 3m 32s	remaining: 1m 37s
# 4900:	learn: 0.0021471	total: 3m 37s	remaining: 1m 33s
# 5000:	learn: 0.0021343	total: 3m 42s	remaining: 1m 28s
# 5100:	learn: 0.0021339	total: 3m 47s	remaining: 1m 24s
# 5200:	learn: 0.0020620	total: 3m 52s	remaining: 1m 20s
# 5300:	learn: 0.0020198	total: 3m 57s	remaining: 1m 15s
# 5400:	learn: 0.0020711	total: 4m 1s	remaining: 1m 11s
# 5500:	learn: 0.0020223	total: 4m 6s	remaining: 1m 7s
# 5600:	learn: 0.0019736	total: 4m 11s	remaining: 1m 2s
# 5700:	learn: 0.0019025	total: 4m 16s	remaining: 58.5s
# 5800:	learn: 0.0019061	total: 4m 21s	remaining: 54s
# 5900:	learn: 0.0019153	total: 4m 26s	remaining: 49.6s
# 6000:	learn: 0.0019063	total: 4m 31s	remaining: 45.1s
# 6100:	learn: 0.0018710	total: 4m 36s	remaining: 40.7s
# 6200:	learn: 0.0018426	total: 4m 40s	remaining: 36.2s
# 6300:	learn: 0.0018211	total: 4m 45s	remaining: 31.7s
# 6400:	learn: 0.0017756	total: 4m 50s	remaining: 27.2s
# 6500:	learn: 0.0017447	total: 4m 55s	remaining: 22.7s
# 6600:	learn: 0.0018059	total: 5m	remaining: 18.2s
# 6700:	learn: 0.0017929	total: 5m 5s	remaining: 13.6s
# 6800:	learn: 0.0017018	total: 5m 10s	remaining: 9.08s
# 6900:	learn: 0.0017705	total: 5m 15s	remaining: 4.52s
# 6999:	learn: 0.0017573	total: 5m 20s	remaining: 0us
# 16 ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 173
#     171 print(loc, "----------------------------------------------------------------------------------------------------")
#     172 data = pd.read_csv(data_dir + f'/data/add_lag_diff/loc_{loc}.csv')
# --> 173 data_late, data_early, data_to_predict = prepare_dataset(data, features)
#     175 # data_late_train, data_late_test = data_late.reset_index().loc[:5500, ], data_late.reset_index().loc[5500:, ]
#     176 minmax_scaler, cat_model, y_scaler = train_model(data_late)
#
# Cell In[2], line 46, in prepare_dataset(data, features)
#      39 # Drop the date that have large gap
#      40 # group_lst = gap_counts[gap_counts['missing_count'] > 60]['gap_group'].values
#      41 # missing_date_lst = data[data['gap_group'].isin(group_lst)]['date'].unique()
#      42 # data = data[~data['date'].isin(missing_date_lst)]
#      43
#      44 # Impute use decomposition
#      45 for feat in features:
# ---> 46     data[feat], data[f'{feat}_deseason'], data[f'{feat}_season_trend'] = time_decompose(data[feat], 60*30, 15)
#      48 # # Get the complete day only
#      49 # data['date'] = pd.to_datetime(data['DateTime']).dt.date
#      50 # record_counts = data.groupby('date').size()
#      51 # data = data[data['date'].isin(list(record_counts[record_counts == 60].index))]
#      52 data['power_lag1'] = feature_differencing(data['Power(mW)_log_deseason'], 1)
#
# Cell In[2], line 16, in time_decompose(data_col, period, season)
#      14 def time_decompose(data_col, period, season):
#      15     stl = STL(data_col.fillna(data_col.interpolate('linear')), period=period, seasonal=season)
# ---> 16     res = stl.fit()
#      17     seasonal_component = res.seasonal
#      18     trend_component = res.trend
#
# File statsmodels/tsa/stl/_stl.pyx:357, in statsmodels.tsa.stl._stl.STL.fit()
#
# File ~/.conda/envs/aicup/lib/python3.9/site-packages/pandas/core/series.py:389, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     384 _mgr: SingleManager
#     386 # ----------------------------------------------------------------------
#     387 # Constructors
# --> 389 def __init__(
#     390     self,
#     391     data=None,
#     392     index=None,
#     393     dtype: Dtype | None = None,
#     394     name=None,
#     395     copy: bool | None = None,
#     396     fastpath: bool | lib.NoDefault = lib.no_default,
#     397 ) -> None:
#     398     if fastpath is not lib.no_default:
#     399         warnings.warn(
#     400             "The 'fastpath' keyword in pd.Series is deprecated and will "
#     401             "be removed in a future version.",
#     402             DeprecationWarning,
#     403             stacklevel=find_stack_level(),
#     404         )
#
# KeyboardInterrupt:

# %%
output = pd.read_csv("upload(no answer).csv")
output = output.merge(all_predictions, left_on='序號', right_on='serial', how='left')

output_stl = pd.read_csv("output_stl_1f.csv")
output['y_pred'] = output['y_pred'].fillna(output_stl['答案'])

output['答案'] = output['y_pred']
output[['序號', '答案']].to_csv('output_stl_deseason.csv', index=False)
